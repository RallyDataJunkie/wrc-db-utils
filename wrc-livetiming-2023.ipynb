# %% [markdown]
# # WRC Live Timing API Scraper
#
# Simple exploration of grabbing data from WRC Live Timing API.

# %%
from urllib.parse import urljoin
from parse import parse

import pandas as pd
import requests

#%pip install requests-cache
import requests_cache
requests_cache.install_cache("demo_cache")
# Out:
# Collecting requests-cache
#   Downloading requests_cache-1.1.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: attrs>=21.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache) (23.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/tonyhirst/Library/Python/3.11/lib/python/site-packages (from requests-cache) (4.1.0)
# Requirement already satisfied: requests>=2.22 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache) (2.31.0)
# Collecting url-normalize>=1.4 (from requests-cache)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: urllib3>=1.25.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-cache) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.22->requests-cache) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.22->requests-cache) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.22->requests-cache) (2023.7.22)
# Requirement already satisfied: six in /Users/tonyhirst/Library/Python/3.11/lib/python/site-packages (from url-normalize>=1.4->requests-cache) (1.16.0)
# Downloading requests_cache-1.1.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: url-normalize, requests-cache
# Successfully installed requests-cache-1.1.1 url-normalize-1.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
WRC_API_BASE = "https://api.wrc.com/content/{path}"

CURRENT_YEAR = 2023
CURRENT_SEASON = 20

seasonId = CURRENT_SEASON

# %%
from itertools import zip_longest


def _WRC_json(path, base=WRC_API_BASE):
    """Return JSON from API."""
    url = urljoin(base, path)
    #print(f"Fetching: {url}")
    r = requests.get(url)
    rj = r.json()
    if "status" in rj and rj["status"]=="Not Found":
        return {}
    return r.json()


def convert_date_range(date_range_str):
    """Convert date of from `19 - 22 JAN 2023` to date range."""
    r = parse("{start_day} - {end_day} {month} {year}", date_range_str)
    start_date = pd.to_datetime(
        f"{r['start_day']} {r['month']} {r['year']}", format="%d %b %Y"
    )
    end_date = pd.to_datetime(
        f"{r['end_day']} {r['month']} {r['year']}", format="%d %b %Y"
    )
    return pd.date_range(start=start_date, end=end_date)


def timeify(df, col, typ=None):
    """Convert a column  to a datetime inplace."""
    if typ == "daterange":
        df[col] = df[col].apply(convert_date_range)
    else:
        df[col] = pd.to_datetime(df[col].astype(int), unit="ms")


def tablify(json_data, subcolkey=None):
    """Generate table from separate colnames/values JSON."""
    # Note that the JSON may be a few rows short cf. provided keys
    if subcolkey is None:
        results = []
        for values in json_data["values"]:
            result_dict = {}
            # Zip keys and values, filling None for missing values
            zipped_values = zip_longest(json_data["fields"], values, fillvalue=None)
            # Convert the zipped values to a dictionary and update the result_dict
            result_dict.update(dict(zipped_values))
            results.append(result_dict)
        return pd.DataFrame(results)
    else:
        df = pd.DataFrame(columns=json_data["fields"])
        for value in json_data["values"]:
            _df = pd.DataFrame(value[subcolkey])
            if len(_df.columns) < len(json_data["fields"]):
                _df[[json_data["fields"][len(_df.columns) :]]] = None
            _df.columns = json_data["fields"]
            for c in [k for k in value.keys() if k != subcolkey]:
                _df[c] = value[c]
                df = pd.concat([df, _df])
        return df

# %% [markdown]
# ## Season Calendar
#
# The API call `https://api.wrc.com/content/filters/calendar` gives a list of current or latest (last, if season's end) events, from which we can get a season identifer. For the 2023 WRC championship, the season ID is `20`

# %%
def getFullCalendar(year=CURRENT_YEAR):
    stub = (
        f"filters/calendar?language=en&size=20&championship=wrc&origin=vcms&year={year}"
    )
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.dataFrame()
    # return json_data
    return pd.DataFrame(json_data["content"])


df_fullcal = getFullCalendar()
df_fullcal.head()
# Out:
# Fetching: https://api.wrc.com/content/filters/calendar?language=en&size=20&championship=wrc&origin=vcms&year=2023
#      id         guid                           title  \
# 0  IQXg  WRC_2023_01              Rallye Monte-Carlo
# 1  lGzi  WRC_2023_02               WRC Rally Sweden
# 2  siDN  WRC_2023_03     WRC Guanajuato Rally México
# 3  rejA  WRC_2023_04               WRC Croatia Rally
# 4  9xIl  WRC_2023_05  WRC Vodafone Rally de Portugal
#
#                         location      startDate        endDate eventId  \
# 0                         Monaco  1674125280000  1674384480000     353
# 1                           Umea  1675940100000  1676199300000     354
# 2               Leon, Guanajuato  1678949100000  1679208300000     355
# 3  Zagreb, City of Zagreb Region  1682059680000  1682232480000     356
# 4              Matosinhos, Porto  1683870600000  1684043400000     357
#
#   rallyId                                        description  round  ...  \
# 0     357  The most unpredictable rally of the year. Rela...      1  ...
# 1     358  The WRC’s ultimate winter challenge. Watch in ...      2  ...
# 2     359  A thrilling ride through the colourful landsca...      3  ...
# 3     360  High-speed stretches meet challenging hairpin ...      4  ...
# 4     361  Fast but technical gravel roads inland from Po...      5  ...
#
#     uid    seriesUid releaseYear    availableOn  availableTill  \
# 0  IQXg  WRC_2023_01        2023  1674125280000  1674384480000
# 1  lGzi  WRC_2023_02        2023  1675940100000  1676199300000
# 2  siDN  WRC_2023_03        2023  1678949100000  1679208300000
# 3  rejA  WRC_2023_04        2023  1682059680000  1682232480000
# 4  9xIl  WRC_2023_05        2023  1683870600000  1684043400000
#
#               startDateLocal               endDateLocal     finishDate  \
# 0  2023-01-19T11:48:00+01:00  2023-01-22T11:48:00+01:00  1674384480000
# 1  2023-02-09T11:55:00+01:00  2023-02-12T11:55:00+01:00  1676199300000
# 2  2023-03-16T00:45:00-06:00  2023-03-19T00:45:00-06:00  1679208300000
# 3  2023-04-21T08:48:00+02:00  2023-04-23T08:48:00+02:00  1682232480000
# 4  2023-05-12T06:50:00+01:00  2023-05-14T06:50:00+01:00  1684043400000
#
#   championship                                   championshipLogo
# 0          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 1          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 2          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 3          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 4          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
#
# [5 rows x 29 columns]

# %%
df_fullcal
# Out:
#       id         guid                               title  \
# 0   IQXg  WRC_2023_01                  Rallye Monte-Carlo
# 1   lGzi  WRC_2023_02                   WRC Rally Sweden
# 2   siDN  WRC_2023_03         WRC Guanajuato Rally México
# 3   rejA  WRC_2023_04                   WRC Croatia Rally
# 4   9xIl  WRC_2023_05      WRC Vodafone Rally de Portugal
# 5   BTVM  WRC_2023_06           WRC Rally Italia Sardegna
# 6   vhG4  WRC_2023_07              WRC Safari Rally Kenya
# 7   38Ly  WRC_2023_08                   WRC Rally Estonia
# 8   Kf3P  WRC_2023_09  WRC Secto Automotive Rally Finland
# 9   aCfi  WRC_2023_10      WRC EKO Acropolis Rally Greece
# 10  ayMP  WRC_2023_11             WRC Rally Chile Bio Bío
# 5   2023-06-01T08:51:00+02:00  2023-06-04T08:51:00+02:00  1685861460000
# 6   2023-06-22T09:52:00+03:00  2023-06-25T09:52:00+03:00  1687675920000
# 7   2023-07-20T09:54:00+03:00  2023-07-23T09:54:00+03:00  1690095240000
# 8   2023-08-02T21:30:00+03:00  2023-08-06T21:29:00+03:00  1691346540000
# 9   2023-09-07T17:44:00+03:00  2023-09-10T14:45:00+03:00  1694346300000
# 10  2023-09-28T08:00:00-03:00  2023-10-01T14:45:00-03:00  1696182300000
# 11  2023-10-25T16:00:00+02:00  2023-10-29T15:00:00+01:00  1698588000000
# 12  2023-11-16T09:00:00+09:00  2023-11-19T16:01:00+09:00  1700377260000
#
#    championship                                   championshipLogo
# 0           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 1           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 2           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 3           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 4           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 5           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 6           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 7           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 8           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 9           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 10          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 11          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 12          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
#
# [13 rows x 29 columns]

# %%
# https://api.wrc.com/content/result/calendar?season=20&championship=wrc


def getResultsCalendar(seasonId=CURRENT_SEASON):
    """Get the WRC Calendar for a given season ID as a JSON result."""
    stub = f"result/calendar?season={seasonId}&championship=wrc"
    json_data = _WRC_json(stub)
    df_calendar = tablify(json_data)
    #timeify(df_calendar, "date", "daterange")
    #timeify(df_calendar, "startDate")
    #timeify(df_calendar, "finishDate")
    # df_calendar.set_index("id", inplace=True)
    return df_calendar

# %%
getResultsCalendar().head()
# Out:
# Fetching: https://api.wrc.com/content/result/calendar?season=20&championship=wrc
#      id                      rallyTitle ROUND rallyCountry rallyCountryImage  \
# 0  IQXg              Rallye Monte-Carlo     1       Monaco     Flags/MCO.png
# 1  lGzi               WRC Rally Sweden      2       Sweden     Flags/SWE.png
# 2  siDN     WRC Guanajuato Rally México     3       Mexico     Flags/MEX.png
# 3  rejA               WRC Croatia Rally     4      Croatia     Flags/HRV.png
# 4  9xIl  WRC Vodafone Rally de Portugal     5     Portugal     Flags/PRT.png
#
#   rallyId              date      startDate     finishDate  \
# 0     357  19 - 22 JAN 2023  1674125280000  1674384480000
# 1     358  09 - 12 FEB 2023  1675940100000  1676199300000
# 2     359  16 - 19 MAR 2023  1678949100000  1679208300000
# 3     360  21 - 23 APR 2023  1682059680000  1682232480000
# 4     361  12 - 14 MAY 2023  1683870600000  1684043400000
#
#                                driverId driverCountryImage           driver  \
# 0  1cf9ade6-25b5-5586-8393-eacfeb943eae      Flags/FRA.png  Sébastien OGIER
# 1  6632e7ca-34bf-55b8-9cad-d060000fa794      Flags/EST.png        Ott TÄNAK
# 2  1cf9ade6-25b5-5586-8393-eacfeb943eae      Flags/FRA.png  Sébastien OGIER
# 3  ae7329c9-79b3-5d96-886c-22cca6217764      Flags/GBR.png      Elfyn EVANS
# 4  d8e4bbea-3af2-5486-9ad5-a445aaec573e      Flags/FIN.png  Kalle ROVANPERÄ
#
#                              coDriverId coDriverCountryImage         coDriver  \
# 0  867cd58f-3fe3-5290-9cc5-b21cb41c523c        Flags/FRA.png  Vincent LANDAIS
# 1  00a8a5c3-f7ba-5086-86df-1a59b7da7e26        Flags/EST.png  Martin JÄRVEOJA
# 2  867cd58f-3fe3-5290-9cc5-b21cb41c523c        Flags/FRA.png  Vincent LANDAIS
# 3  53e56691-fe7c-5271-9dc5-8960df28b221        Flags/GBR.png     Scott MARTIN
# 4  e4dd8a3f-00e9-59f7-9871-9337af6085d7        Flags/FIN.png  Jonne HALTTUNEN
#
#                                  teamId          teamLogo  \
# 0  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
# 1  887309d0-48be-5f83-ad3e-abf2a79a64a3    Flags/ford.png
# 2  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
# 3  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
# 4  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
#
#                         teamName manufacturer
# 0        TOYOTA GAZOO RACING WRT       Toyota
# 1  M-SPORT FORD WORLD RALLY TEAM         Ford
# 2        TOYOTA GAZOO RACING WRT       Toyota
# 3        TOYOTA GAZOO RACING WRT       Toyota
# 4        TOYOTA GAZOO RACING WRT       Toyota

# %%
eventId, rallyId = df_fullcal.iloc[-1][["eventId", "rallyId"]]
eventId, rallyId
# Out:
# ('365', '369')

# %%
## Stages


def getStageDetails(eventId, rallyId):
    stub = f"result/stages?eventId={eventId}&rallyId={rallyId}&championship=wrc"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.dataFrame()
    df_stageDetails = tablify(json_data)
    return df_stageDetails


df_stageDetails = getStageDetails(eventId, rallyId)
df_stageDetails.head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/stages?eventId=365&rallyId=369&championship=wrc
#                                      id STAGE                   STAGE TYPE  \
# 0  ee55daa1-fd07-574f-835a-f39008081b95   SHD                    shakedown
# 1  3cd7a38a-436f-5c21-b966-8b4743f20a57   SS1  HeadToHeadSuperSpecialStage
# 2  7ae2243b-6746-516b-895e-16b5d0a2ed51   SS2                 SpecialStage
#
#   stageId eventId       STATUS       day                              name  \
# 0     SHD     365     Complete                                   Shakedown
# 1    6119     365    Completed  Thursday  SS1 TOYOTA STADIUM SSS 1 (2.1km)
# 2    6120     365  Interrupted    Friday  SS2 Isegami's Tunnel 1 (23.67km)
#
#   distance
# 0
# 1      2.1
# 2    23.67

# %%
def getOverall(eventId, rallyId, stageId, championship="wrc"):
    stub = f"result/stageResult?eventId={eventId}&rallyId={rallyId}&stageId={stageId}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_overall = tablify(json_data)
    return df_overall


stageId = df_stageDetails.iloc[-1]["stageId"]

getOverall(eventId, rallyId, stageId).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
#                                      id pos carNo  \
# 0  c991bcbd-6d9a-5efc-8bde-53d1c3bacae5   1   #33
# 1  2141d91f-8620-5848-8873-32f48a37f2d7   2   #17
# 2  0b585f28-25f4-5d7f-be34-6ef26f0e086e   3   #69
#
#                                driverId  \
# 0  ae7329c9-79b3-5d96-886c-22cca6217764
# 1  1cf9ade6-25b5-5586-8393-eacfeb943eae
# 2  d8e4bbea-3af2-5486-9ad5-a445aaec573e
#
#                                        driverCountry driverCountryImage  \
# 0  United Kingdom of Great Britain and Northern I...      Flags/GBR.png
# 1                                             France      Flags/FRA.png
# 2                                            Finland      Flags/FIN.png
#
#             driver                            coDriverId  \
# 0      Elfyn EVANS  53e56691-fe7c-5271-9dc5-8960df28b221
# 1  Sébastien OGIER  867cd58f-3fe3-5290-9cc5-b21cb41c523c
# 2  Kalle ROVANPERÄ  e4dd8a3f-00e9-59f7-9871-9337af6085d7
#
#                                      coDriverCountry coDriverCountryImage  \
# 0  United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 1                                             France        Flags/FRA.png
# 2                                            Finland        Flags/FIN.png
#
#    ...                team/car teamName             teamLogo eligibility  \
# 0  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
# 1  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
# 2  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
#
#    stageTime penaltyTime  totalTime diffFirst diffPrev groupClass
# 0  3:32:08.8              3:32:08.8                           RC1
# 1  3:32:26.5      1:00.0  3:33:26.5   +1:17.7  +1:17.7        RC1
# 2  3:33:55.3              3:33:55.3   +1:46.5    +28.8        RC1
#
# [3 rows x 22 columns]

# %%
def getStageTimes(eventId, rallyId, stageId, championship="wrc"):
    stub = f"result/stageTimes?eventId={eventId}&rallyId={rallyId}&stageId={stageId}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_stageTimes = tablify(json_data)
    return df_stageTimes


getStageTimes(eventId, rallyId, stageId).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
#                                      id pos carNo  \
# 0  c991bcbd-6d9a-5efc-8bde-53d1c3bacae5   1   #33
# 1  2141d91f-8620-5848-8873-32f48a37f2d7   2   #17
# 2  0b585f28-25f4-5d7f-be34-6ef26f0e086e   3   #69
#
#                                driverId  \
# 0  ae7329c9-79b3-5d96-886c-22cca6217764
# 1  1cf9ade6-25b5-5586-8393-eacfeb943eae
# 2  d8e4bbea-3af2-5486-9ad5-a445aaec573e
#
#                                        driverCountry driverCountryImage  \
# 0  United Kingdom of Great Britain and Northern I...      Flags/GBR.png
# 1                                             France      Flags/FRA.png
# 2                                            Finland      Flags/FIN.png
#
#             driver                            coDriverId  \
# 0      Elfyn EVANS  53e56691-fe7c-5271-9dc5-8960df28b221
# 1  Sébastien OGIER  867cd58f-3fe3-5290-9cc5-b21cb41c523c
# 2  Kalle ROVANPERÄ  e4dd8a3f-00e9-59f7-9871-9337af6085d7
#
#                                      coDriverCountry coDriverCountryImage  \
# 0  United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 1                                             France        Flags/FRA.png
# 2                                            Finland        Flags/FIN.png
#
#    ...                team/car teamName             teamLogo eligibility  \
# 0  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
# 1  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
# 2  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
#
#    stageTime penaltyTime  totalTime diffFirst diffPrev groupClass
# 0  3:32:08.8              3:32:08.8                           RC1
# 1  3:32:26.5      1:00.0  3:33:26.5   +1:17.7  +1:17.7        RC1
# 2  3:33:55.3              3:33:55.3   +1:46.5    +28.8        RC1
#
# [3 rows x 22 columns]

# %%
getStageTimes(365, 369, 4161).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4161&championship=wrc
# Empty DataFrame
# Columns: []
# Index: []

# %%
def getSplitTimes(eventId, rallyId, stageId, championship="wrc"):
    stub = f"result/splitTime?eventId={eventId}&rallyId={rallyId}&stageId={stageId}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_splitTimes = tablify(json_data)
    return df_splitTimes


getSplitTimes(eventId, rallyId, stageId).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
#                                      id pos carNo  \
# 0  c991bcbd-6d9a-5efc-8bde-53d1c3bacae5   1   #33
# 1  2141d91f-8620-5848-8873-32f48a37f2d7   2   #17
# 2  0b585f28-25f4-5d7f-be34-6ef26f0e086e   3   #69
#
#                                driverId  \
# 0  ae7329c9-79b3-5d96-886c-22cca6217764
# 1  1cf9ade6-25b5-5586-8393-eacfeb943eae
# 2  d8e4bbea-3af2-5486-9ad5-a445aaec573e
#
#                                        driverCountry driverCountryImage  \
# 0  United Kingdom of Great Britain and Northern I...      Flags/GBR.png
# 1                                             France      Flags/FRA.png
# 2                                            Finland      Flags/FIN.png
#
#             driver                            coDriverId  \
# 0      Elfyn EVANS  53e56691-fe7c-5271-9dc5-8960df28b221
# 1  Sébastien OGIER  867cd58f-3fe3-5290-9cc5-b21cb41c523c
# 2  Kalle ROVANPERÄ  e4dd8a3f-00e9-59f7-9871-9337af6085d7
#
#                                      coDriverCountry coDriverCountryImage  \
# 0  United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 1                                             France        Flags/FRA.png
# 2                                            Finland        Flags/FIN.png
#
#    ...                team/car teamName             teamLogo eligibility  \
# 0  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
# 1  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
# 2  ...  GR Yaris Rally1 HYBRID   Toyota  teamLogo/toyota.png           M
#
#    stageTime penaltyTime  totalTime diffFirst diffPrev groupClass
# 0  3:32:08.8              3:32:08.8                           RC1
# 1  3:32:26.5      1:00.0  3:33:26.5   +1:17.7  +1:17.7        RC1
# 2  3:33:55.3              3:33:55.3   +1:46.5    +28.8        RC1
#
# [3 rows x 22 columns]

# %%
getSplitTimes(eventId, rallyId, stageId).columns
# Out:
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Index(['id', 'pos', 'carNo', 'driverId', 'driverCountry', 'driverCountryImage',
#        'driver', 'coDriverId', 'coDriverCountry', 'coDriverCountryImage',
#        'coDriver', 'teamId', 'team/car', 'teamName', 'teamLogo', 'eligibility',
#        'stageTime', 'penaltyTime', 'totalTime', 'diffFirst', 'diffPrev',
#        'groupClass'],
#       dtype='object')

# %%
def getStageWinners(eventId):
    stub = f"result/stageWinners?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_stageWinners = tablify(json_data)
    return df_stageWinners


getStageWinners(eventId).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/stageWinners?eventId=365
#     id carNo stageNo                      stageName  \
# 0  365   #11     SS1  TOYOTA STADIUM SSS 1 (2.1 km)
# 1  365   #33     SS2  Isegami's Tunnel 1 (23.67 km)
# 2  365   #33     SS3         Inabu Dam 1 (19.38 km)
#
#                      stageType stageId                               eventId  \
# 0  HeadToHeadSuperSpecialStage    6119  a0d04378-f379-53ff-a3b2-aa8b3e27a3f0
# 1                 SpecialStage    6120  a0d04378-f379-53ff-a3b2-aa8b3e27a3f0
# 2                 SpecialStage    6121  a0d04378-f379-53ff-a3b2-aa8b3e27a3f0
#
#                                 entryId                              driverId  \
# 0  6004e998-29a1-5a2e-b020-548227878bfe  c99a2a26-bd03-5153-aaa7-684d3acb5491
# 1  94ad0762-7c1b-53b9-85e3-c39e88f4d105  ae7329c9-79b3-5d96-886c-22cca6217764
# 2  94ad0762-7c1b-53b9-85e3-c39e88f4d105  ae7329c9-79b3-5d96-886c-22cca6217764
#
#                                        driverCountry  ...  \
# 0                                            Belgium  ...
# 1  United Kingdom of Great Britain and Northern I...  ...
# 2  United Kingdom of Great Britain and Northern I...  ...
#
#                              coDriverId  \
# 0  b1b98699-0332-528a-8a80-11eb538f1ded
# 1  53e56691-fe7c-5271-9dc5-8960df28b221
# 2  53e56691-fe7c-5271-9dc5-8960df28b221
#
#                                      coDriverCountry coDriverCountryImage  \
# 0                                            Belgium        Flags/BEL.png
# 1  United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 2  United Kingdom of Great Britain and Northern I...        Flags/GBR.png
#
#            coDriver                                teamId  \
# 0  Martijn WYDAEGHE  b6692ea5-df92-5cad-a91c-20319a6fffd7
# 1      Scott MARTIN  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6
# 2      Scott MARTIN  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6
#
#                  team/car teamName              teamLogo eligibility     time
# 0     i20 N Rally1 HYBRID  Hyundai  teamLogo/hyundai.png           M   1:47.6
# 1  GR Yaris Rally1 HYBRID   Toyota   teamLogo/toyota.png           M  20:17.8
# 2  GR Yaris Rally1 HYBRID   Toyota   teamLogo/toyota.png           M  14:20.0
#
# [3 rows x 22 columns]

# %%
def getItinerary(eventId):
    stub = f"result/itinerary?eventId={eventId}&extended=false"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_itinerary = tablify(json_data, "values")
    return df_itinerary


getItinerary(eventId).tail(3)
# Out:
# Fetching: https://api.wrc.com/content/result/itinerary?eventId=365&extended=false
# namecols 4
#   stage eventId                               stageId  distance  \
# 3  SS20     365  128c0d05-4538-536f-a7d2-f929836d1dc4  22.92 km
# 4  SS21     365  a9e4c371-57ba-5c72-8fff-8b92a95baa60   11.6 km
# 5  SS22     365  4a0db031-0143-5756-af1f-e87945227001   7.52 km
#
#   timingPrecision firstCarDueDateTime      firstCarDueDateTimeMs  \
# 3          Minute               11:04  2023-11-19T11:04:00+09:00
# 4          Minute               11:57  2023-11-19T11:57:00+09:00
# 5          Minute               14:15  2023-11-19T14:15:00+09:00
#
#   controlPenalties     status        type                         location  \
# 3             None  Completed  StageStart                       Ena City 2
# 4             None  Completed  StageStart                  Nenoue Kougen 2
# 5             None  Completed  StageStart  Wolf Power Stage Asahi Kougen 2
#
#   targetDuration targetDurationMs      id  order                  date
# 3       00:03:00           180000  1095.0    4.0  Sunday 19th November
# 4       00:03:00           180000  1095.0    4.0  Sunday 19th November
# 5       00:03:00           180000  1095.0    4.0  Sunday 19th November

# %%
def getStartlist(eventId):
    stub = f"result/startLists?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_startlist = tablify(json_data, "startListItems")
    return df_startlist


getStartlist(eventId).tail(3)
# Out:
# Fetching: https://api.wrc.com/content/result/startLists?eventId=365
# namecols 5
#    order         startDateTimeLocal carNo  \
# 29    30  2023-11-19T05:34:00+09:00   #45
# 30    31  2023-11-19T05:34:00+09:00   #47
# 31    32  2023-11-19T05:34:00+09:00   #48
#
#                                 driverId driverCountry driverCountryImage  \
# 29  3ab588df-cc06-5017-8ba6-143de81a5972         Japan      Flags/JPN.png
# 30  8584c859-11be-5de8-9ba1-f91976ec0b46         Japan      Flags/JPN.png
# 31  4f12d0bb-2cbd-586a-86df-0844b79ef0d3         Japan      Flags/JPN.png
#
#               driver                            coDriverId coDriverCountry  \
# 29       Koji TAKATA  a655075d-d4b8-5790-b96c-ed6480de882c           Japan
# 30      Satoshi IRIE  7336f886-56da-5a98-b9a8-fc626172e583           Japan
# 31  Hiroyasu SHIMIZU  bba42333-aeba-5102-8f37-191cf8de0723           Japan
#
#    coDriverCountryImage          coDriver  \
# 29        Flags/JPN.png  Takashi SEKIMOTO
# 30        Flags/JPN.png  Satoshi KAGEYAMA
# 31        Flags/JPN.png    Takahiro YASUI
#
#                                   teamId  team/car teamName  \
# 29  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  GR Yaris   Toyota
# 30  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6      Vitz   Toyota
# 31  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6     Yaris   Toyota
#
#                teamLogo eligibility groupClass priority  \
# 29  teamLogo/toyota.png                 JRCar1     None
# 30  teamLogo/toyota.png                 JRCar3     None
# 31  teamLogo/toyota.png                 JRCar3     None
#
#                                       id               date
# 29  d5126c53-c54e-514f-8b16-16ff6b9b1050  Sunday 2023-11-19
# 30  d5126c53-c54e-514f-8b16-16ff6b9b1050  Sunday 2023-11-19
# 31  d5126c53-c54e-514f-8b16-16ff6b9b1050  Sunday 2023-11-19

# %%
def getPenalties(eventId):
    stub = f"result/penalty?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_penalties = tablify(json_data)
    return df_penalties


getPenalties(eventId).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/penalty?eventId=365
#      id carNo                              driverId driverCountry  \
# 0  4844   #46  e2464489-5926-5ac0-94a3-bdbf823bb827         Japan
# 1  4845   #34  d6030311-c622-5262-8a0e-8fb4e30bcc29         Japan
# 2  4846   #34  d6030311-c622-5262-8a0e-8fb4e30bcc29         Japan
#
#   driverCountryImage             driver                            coDriverId  \
# 0      Flags/JPN.png  Yasunori HAGIWARA  e6f37ce0-7731-5942-996d-63cde99f1e23
# 1      Flags/JPN.png         Toshi ARAI  05b11bf7-a75c-53e7-87eb-9ea080333b1c
# 2      Flags/JPN.png         Toshi ARAI  05b11bf7-a75c-53e7-87eb-9ea080333b1c
#
#   coDriverCountry coDriverCountryImage          coDriver  ... eligibility  \
# 0           Japan        Flags/JPN.png     Koichi HARADA  ...
# 1           Japan        Flags/JPN.png  Yuichi MATSUMOTO  ...
# 2           Japan        Flags/JPN.png  Yuichi MATSUMOTO  ...
#
#   groupClass rallyId entryId controlId penaltyTime penaltyDuration  \
# 0     JRCar1     369   47504     25793        40.0           PT40S
# 1     JRCar1     369   47494     25765        10.0           PT10S
# 2     JRCar1     369   47494     25765        10.0           PT10S
#
#   penaltyDurationMs       reason control
# 0             40000  4 MINS LATE     TC1
# 1             10000   1 MIN LATE    TC1D
# 2             10000   1 MIN LATE    TC1D
#
# [3 rows x 24 columns]

# %%
def getRetirements(eventId):
    stub = f"result/retirements?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_retirements = tablify(json_data)
    return df_retirements


getRetirements(eventId).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/retirements?eventId=365
#      id carNo                              driverId driverCountry  \
# 0  6768   #36  0a4d6b0a-f926-56f3-aca2-049f93add127         Japan
# 1  6769   #36  0a4d6b0a-f926-56f3-aca2-049f93add127         Japan
# 2  6770    #6  d06b6c54-863a-533d-9241-9dd04f7acb85         Spain
#
#   driverCountryImage            driver                            coDriverId  \
# 0      Flags/JPN.png  Tomoyuki SHINKAI  8e4b14a8-433b-5001-b586-0f5cf15edf1f
# 1      Flags/JPN.png  Tomoyuki SHINKAI  8e4b14a8-433b-5001-b586-0f5cf15edf1f
# 2      Flags/ESP.png      Daniel SORDO  a1254acc-3431-5641-97c1-412d3713945c
#
#   coDriverCountry coDriverCountryImage         coDriver  ...  \
# 0           Japan        Flags/JPN.png      Yuichi ANDO  ...
# 1           Japan        Flags/JPN.png      Yuichi ANDO  ...
# 2           Spain        Flags/ESP.png  Cándido CARRERA  ...
#
#               team/car teamName              teamLogo eligibility groupClass  \
# 0             GR Yaris   Toyota   teamLogo/toyota.png                 JRCar1
# 1             GR Yaris   Toyota   teamLogo/toyota.png                 JRCar1
# 2  i20 N Rally1 HYBRID  Hyundai  teamLogo/hyundai.png           M        RC1
#
#   rallyId entryId controlId    reason control
# 0     369   47496     25795  ACCIDENT     SF1
# 1     369   47496     25763  REJOINED    TC1B
# 2     369   47479     25798  ACCIDENT     SF2
#
# [3 rows x 21 columns]

# %%
def getChampionship(
    seasonId, eventId, championshipId, championship_type, championship="wrc"
):
    stub = f"result/championshipresult?seasonId={seasonId}&eventId={eventId}&championshipId={championshipId}&type={championship_type}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_splitTimes = tablify(json_data)
    return df_splitTimes


championship_type = "driver"  # where is list?
championshipId = None  # where is list?

getChampionship(seasonId, eventId, championshipId, championship_type).head(3)
# Out:
# Fetching: https://api.wrc.com/content/result/championshipresult?seasonId=20&eventId=365&championshipId=None&type=driver&championship=wrc
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb Cell 22 line 1
#      <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=11'>12</a> championship_type = "driver"  # where is list?
#      <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=12'>13</a> championshipId = None  # where is list?
# ---> <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=14'>15</a> getChampionship(seasonId, eventId, championshipId, championship_type).head(3)
#
# /Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb Cell 22 line 8
#       <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=5'>6</a> if not json_data:
#       <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=6'>7</a>     return pd.DataFrame()
# ----> <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=7'>8</a> df_splitTimes = tablify(json_data)
#       <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=8'>9</a> return df_splitTimes
#
# /Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb Cell 22 line 4
#      <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=37'>38</a> if subcolkey is None:
#      <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=38'>39</a>     results = []
# ---> <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=39'>40</a>     for values in json_data["values"]:
#      <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=40'>41</a>         result_dict = {}
#      <a href='vscode-notebook-cell:/Users/tonyhirst/Documents/GitHub/wrc-db-utils/wrc-livetiming-2023.ipynb#X46sZmlsZQ%3D%3D?line=41'>42</a>         # Zip keys and values, filling None for missing values
#
# KeyError: 'values'

# %%
import sqlite_utils
#!rm wrc_2023_results.db
db = sqlite_utils.Database("wrc_2023_results.db")

# %%
# db["delme"].insert_all(df_fullcal.to_dict("records"))
# db["delme"].drop()

# %%
def db_add(table, df):
    if not df.empty:
        db[table].insert_all(df.to_dict("records"), alter=True)

db_add("fullcal", getFullCalendar())
db_add("resultscal", getResultsCalendar())
# Out:
# Fetching: https://api.wrc.com/content/filters/calendar?language=en&size=20&championship=wrc&origin=vcms&year=2023
# Fetching: https://api.wrc.com/content/result/calendar?season=20&championship=wrc

# %%
# We can add alter=True to dynamically modify tables

def stageresults(row):
    stageId = row["stageId"]
    db_add("stagetimes",
        getStageTimes(eventId, rallyId, stageId))
    db_add("splittimes",
        getSplitTimes(eventId, rallyId, stageId))
    db_add("overall",
        getOverall(eventId, rallyId, stageId))


def rallyresults(row):
    eventId, rallyId = row[["eventId", "rallyId"]]
    db_add("retirements",getRetirements(eventId))
    db_add("penalties",getPenalties(eventId))
    db_add("startlist",getStartlist(eventId))
    db_add("itinerary",getItinerary(eventId))
    db_add("stagewinners",getStageWinners(eventId))

    df_stageDetails = getStageDetails(eventId, rallyId)
    db_add("stagedetails",df_stageDetails)
    df_stageDetails.apply(stageresults, axis=1)


_ = df_fullcal.apply(rallyresults, axis=1)
# Out:
# Fetching: https://api.wrc.com/content/result/retirements?eventId=353
# Fetching: https://api.wrc.com/content/result/penalty?eventId=353
# Fetching: https://api.wrc.com/content/result/startLists?eventId=353
# namecols 5
# Fetching: https://api.wrc.com/content/result/itinerary?eventId=353&extended=false
# namecols 4
# Fetching: https://api.wrc.com/content/result/stageWinners?eventId=353
# Fetching: https://api.wrc.com/content/result/stages?eventId=353&rallyId=357&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4161&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4161&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4161&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4160&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4160&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4160&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4168&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4168&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4168&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4169&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4169&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4169&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4170&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4170&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4170&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4174&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4174&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4174&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4175&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4175&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4175&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4176&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4176&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4176&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4173&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4173&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4173&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4172&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4172&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4172&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4171&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4171&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4171&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4167&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4167&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4167&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4166&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4166&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4166&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4165&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4165&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4165&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4159&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4159&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4159&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4164&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4164&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4164&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4163&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4163&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4163&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4162&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4162&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4162&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Fetching: https://api.wrc.com/content/result/retirements?eventId=354
# Fetching: https://api.wrc.com/content/result/penalty?eventId=354
# Fetching: https://api.wrc.com/content/result/startLists?eventId=354
# namecols 5
# Fetching: https://api.wrc.com/content/result/itinerary?eventId=354&extended=false
# namecols 4
# Fetching: https://api.wrc.com/content/result/stageWinners?eventId=354
# Fetching: https://api.wrc.com/content/result/stages?eventId=354&rallyId=358&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4429&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4429&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4429&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4430&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4430&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4430&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4432&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4432&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4432&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4433&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4433&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4433&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4434&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4434&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4434&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4436&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4436&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4436&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4437&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4437&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4437&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4438&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4438&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4438&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4439&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4439&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4439&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4445&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4445&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4445&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4444&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4444&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4444&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4443&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4443&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4443&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4442&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4442&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4442&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4441&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4441&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4441&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4440&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4440&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4440&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4435&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4435&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4435&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4431&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4431&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4431&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4428&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4428&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4428&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=FINAL&championship=wrc
# Fetching: https://api.wrc.com/content/result/retirements?eventId=355
# Fetching: https://api.wrc.com/content/result/penalty?eventId=355
# Fetching: https://api.wrc.com/content/result/startLists?eventId=355
# namecols 9
# Fetching: https://api.wrc.com/content/result/itinerary?eventId=355&extended=false
# namecols 4
# Fetching: https://api.wrc.com/content/result/stageWinners?eventId=355
# Fetching: https://api.wrc.com/content/result/stages?eventId=355&rallyId=359&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=SHD&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4620&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4620&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4620&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4615&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4615&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4615&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4626&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4626&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4626&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4627&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4627&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4627&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4628&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=4628&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageResult?eventId=365&rallyId=369&stageId=4628&championship=wrc
# Fetching: https://api.wrc.com/content/result/stageTimes?eventId=365&rallyId=369&stageId=4633&championship=wrc
# Fetching: https://api.wrc.com/content/result/splitTime?eventId=365&rallyId=369&stageId=
# 9                                               Japan      Flags/JPN.png
# 10                                              Japan      Flags/JPN.png
# 11                                             Poland      Flags/POL.png
# 12                                            Belgium      Flags/BEL.png
# 13                                            Ireland      Flags/IRL.png
# 14                                              Japan      Flags/JPN.png
# 15                                              Japan      Flags/JPN.png
# 16                                              Japan      Flags/JPN.png
# 17                                              Spain      Flags/ESP.png
# 18                                              Japan      Flags/JPN.png
# 19                                              Japan      Flags/JPN.png
# 20                                              Japan      Flags/JPN.png
# 21                                             Canada      Flags/CAN.png
# 22                                              Japan      Flags/JPN.png
# 23                                              Japan      Flags/JPN.png
# 24                                              Japan      Flags/JPN.png
# 25                                              Japan      Flags/JPN.png
# 26                                              Japan      Flags/JPN.png
# 27                                              Japan      Flags/JPN.png
#
#                   driver                            coDriverId  \
# 0            Elfyn EVANS  53e56691-fe7c-5271-9dc5-8960df28b221
# 1        Sébastien OGIER  867cd58f-3fe3-5290-9cc5-b21cb41c523c
# 2        Kalle ROVANPERÄ  e4dd8a3f-00e9-59f7-9871-9337af6085d7
# 3         Esapekka LAPPI  2ef28d31-4a74-5794-b720-12c327c941b6
# 4       Takamoto KATSUTA  6347a621-eade-5fff-a7b4-7c4b73651e8a
# 5              Ott TÄNAK  00a8a5c3-f7ba-5086-86df-1a59b7da7e26
# 6      Andreas MIKKELSEN  5d0fb669-fb61-5d51-805b-d09c1ac7e36a
# 7        Nikolay GRYAZIN  7d63ec40-0bb6-5da3-954e-846a2d40a9a1
# 8   Kajetan KAJETANOWICZ  a488aa5c-affc-5f48-a95e-0f400495fd71
# 9            Hiroki ARAI  4f879f5d-2cce-5127-bf65-eb4034aee5f6
# 10        Osamu FUKUNAGA  037327bb-b1e5-5db9-9f35-97747020724c
# 11         Daniel CHWIST  ff1f11ca-f1dd-5b29-a16d-0af9510aa46c
# 12      Thierry NEUVILLE  b1b98699-0332-528a-8a80-11eb538f1ded
# 13         Eamonn BOLAND  a8a99c77-b74a-592e-852b-aebea61cc30c
# 14      Tomoyuki SHINKAI  8e4b14a8-433b-5001-b586-0f5cf15edf1f
# 15        Kohsuke MURATA  4bfce1b0-99ed-55e2-8e7e-a1d52f250732
# 16         Yuta YAMAMOTO  1d8f0f30-abe3-5c8e-9ac3-f9cc9be9f3a4
# 17   Miguel DÍAZ ABOITIZ  91f64ca1-c090-5d73-9e25-ba969fdf52df
# 18    Mitsuhiro KUNISAWA  b57311ff-0e08-5f28-8806-efb80bfd6356
# 19        Tohru NAKAYAMA  33c345d3-dbfe-558b-b4c6-c91c819a5117
# 20       Yasuyuki SASAKI  2e3502eb-60d4-5f14-9469-338e2327b98c
# 21          Jason BAILEY  64c84e95-2453-5d25-9309-7c7cfb8ba817
# 22        Taisuke AIHARA  5b273c48-7e5f-56c6-8890-7d6753cd88c8
# 23          Satoshi IMAI  ce5d6a41-d103-51fe-8b44-2cb3776f8831
# 24          Makoto HOTTA  3614d98b-2077-5896-a218-89d91d96c1d7
# 25     Yasunori HAGIWARA  e6f37ce0-7731-5942-996d-63cde99f1e23
# 26           Koji TAKATA  a655075d-d4b8-5790-b96c-ed6480de882c
# 27      Hiroyasu SHIMIZU  bba42333-aeba-5102-8f37-191cf8de0723
#
#                                       coDriverCountry coDriverCountryImage  \
# 0   United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 1                                              France        Flags/FRA.png
# 2                                             Finland        Flags/FIN.png
# 3                                             Finland        Flags/FIN.png
# 4                                             Ireland        Flags/IRL.png
# 5                                             Estonia        Flags/EST.png
# 6                                              Norway        Flags/NOR.png
# 7                                                 ANA        Flags/ANA.png
# 8                                              Poland        Flags/POL.png
# 9                                               Japan        Flags/JPN.png
# 10                                              Japan        Flags/JPN.png
# 11                                             Poland        Flags/POL.png
# 12                                            Belgium        Flags/BEL.png
# 13                                            Ireland        Flags/IRL.png
# 14                                              Japan        Flags/JPN.png
# 15                                              Japan        Flags/JPN.png
# 16                                              Japan        Flags/JPN.png
# 17                                              Spain        Flags/ESP.png
# 18                                              Japan        Flags/JPN.png
# 19                                              Japan        Flags/JPN.png
# 20                                              Japan        Flags/JPN.png
# 21                                             Canada        Flags/CAN.png
# 22                                              Japan        Flags/JPN.png
# 23                                        New Zealand        Flags/NZL.png
# 24                                              Japan        Flags/JPN.png
# 25                                              Japan        Flags/JPN.png
# 26                                              Japan        Flags/JPN.png
# 27                                              Japan        Flags/JPN.png
#
#     ...                team/car  teamName               teamLogo  \
# 0   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 1   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 2   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 3   ...     i20 N Rally1 HYBRID   Hyundai   teamLogo/hyundai.png
# 4   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 5   ...      Puma Rally1 HYBRID      Ford      teamLogo/ford.png
# 6   ...                Fabia RS     Skoda     teamLogo/skoda.png
# 7   ...                Fabia RS     Skoda     teamLogo/skoda.png
# 8   ...                Fabia RS     Skoda     teamLogo/skoda.png
# 9   ...              208 Rally4   Peugeot   teamLogo/peugeot.png
# 10  ...               Fabia Evo     Skoda     teamLogo/skoda.png
# 11  ...               Fabia Evo     Skoda     teamLogo/skoda.png
# 12  ...     i20 N Rally1 HYBRID   Hyundai   teamLogo/hyundai.png
# 13  ...                      C3   Citroen   teamLogo/citroen.png
# 14  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 15  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 16  ...                      86    Toyota    teamLogo/toyota.png
# 17  ...                Fabia RS     Skoda     teamLogo/skoda.png
# 18  ...            Clio RS Line   Renault   teamLogo/renault.png
# 19  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 20  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 21  ...           Fiesta Rally3      Ford      teamLogo/ford.png
# 22  ...                   Copen  Daihatsu  teamLogo/daihatsu.png
# 23  ...                      C3   Citroen   teamLogo/citroen.png
# 24  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 25  ...            WRX Sti 2015    Subaru    teamLogo/subaru.png
# 26  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 27  ...                   Yaris    Toyota    teamLogo/toyota.png
#
#        eligibility  stageTime penaltyTime  totalTime   diffFirst  diffPrev  \
# 0                M  3:32:08.8              3:32:08.8
# 1                M  3:32:26.5      1:00.0  3:33:26.5     +1:17.7   +1:17.7
# 2                M  3:33:55.3              3:33:55.3     +1:46.5     +28.8
# 3                M  3:34:59.1              3:34:59.1     +2:50.3   +1:03.8
# 4                   3:34:09.1      1:10.0  3:35:19.1     +3:10.3     +20.0
# 5                M  3:35:37.1              3:35:37.1     +3:28.3     +18.0
# 6       WRC2 (T/D)  3:39:42.5              3:39:42.5     +7:33.7   +4:05.4
# 7   WRC2 (T/DC/CC)  3:40:58.4              3:40:58.4     +8:49.6   +1:15.9
# 8     WRC2 (DC/CC)  3:51:34.7              3:51:34.7    +19:25.9  +10:36.3
# 9                   3:54:31.5              3:54:31.5    +22:22.7   +2:56.8
# 10   WRC2 (DCM/CC)  3:56:47.8              3:56:47.8    +24:39.0   +2:16.3
# 11    WRC2 (DC/CC)  4:00:01.8              4:00:01.8    +27:53.0   +3:14.0
# 12               M  4:00:13.5              4:00:13.5    +28:04.7     +11.7
# 13  WRC2 (DCM/CCM)  4:00:47.4              4:00:47.4    +28:38.6     +33.9
# 14                  4:07:40.4        10.0  4:07:50.4    +35:41.6   +7:03.0
# 15                  4:11:57.6              4:11:57.6    +39:48.8   +4:07.2
# 16                  4:18:58.5        10.0  4:19:08.5    +46:59.7   +7:10.9
# 17   WRC2 (DCM/CC)  4:32:39.2              4:32:39.2  +1:00:30.4  +13:30.7
# 18                  4:37:03.1              4:37:03.1  +1:04:54.3   +4:23.9
# 19                  4:41:25.1      1:00.0  4:42:25.1  +1:10:16.3   +5:22.0
# 20                  5:02:45.8              5:02:45.8  +1:30:37.0  +20:20.7
# 21       WRC3 (DM)  5:00:05.7      3:00.0  5:03:05.7  +1:30:56.9     +19.9
# 22                  5:06:03.9        20.0  5:06:23.9  +1:34:15.1   +3:18.2
# 23    WRC2 (DC/CC)  5:19:31.7              5:19:31.7  +1:47:22.9  +13:07.8
# 24                  5:19:22.0      1:00.0  5:20:22.0  +1:48:13.2     +50.3
# 25                  5:17:41.4      5:30.0  5:23:11.4  +1:51:02.6   +2:49.4
# 26                  5:52:59.5        40.0  5:53:39.5  +2:21:30.7  +30:28.1
# 27                  5:57:43.1              5:57:43.1  +2:25:34.3   +4:03.6
#
#    groupClass
# 0         RC1
# 1         RC1
# 2         RC1
# 3         RC1
# 4         RC1
# 5         RC1
# 6         RC2
# 7         RC2
# 8         RC2
# 9         RC4
# 10        RC2
# 11        RC2
# 12        RC1
# 13        RC2
# 14     JRCar1
# 15     JRCar1
# 16     JRCar2
# 17        RC2
# 18        RC5
# 19     JRCar1
# 20     JRCar1
# 21        RC3
# 22     JRCar3
# 23        RC2
# 24     JRCar1
# 25     JRCar1
# 26     JRCar1
# 27     JRCar3
#
# [28 rows x 22 columns]

# %%
for row in db.query("select DISTINCT(eventId) from stagedetails "):
    print(row)
# Out:
# {'eventId': '353'}
# {'eventId': '354'}
# {'eventId': '355'}
# {'eventId': '356'}
# {'eventId': '357'}
# {'eventId': '358'}
# {'eventId': '359'}
# {'eventId': '360'}
# {'eventId': '361'}
# {'eventId': '362'}
# {'eventId': '363'}
# {'eventId': '364'}
# {'eventId': '365'}
