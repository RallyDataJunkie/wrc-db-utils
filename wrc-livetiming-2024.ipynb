# %% [markdown]
# # WRC Live Timing API Scraper
#
# Simple exploration of grabbing data from WRC Live Timing API.
#
# TO DO - how do we lookup `championshipId`?

# %%
from urllib.parse import urljoin
from parse import parse
import pathlib

import pandas as pd
import requests

#%pip install requests-cache
import requests_cache
requests_cache.install_cache("demo_cache2")

# %%
CURRENT_YEAR = 2023

WRC_API_BASE = "https://api.wrc.com/content/{path}"

# %%
from itertools import zip_longest


def _WRC_json(path, base=WRC_API_BASE, retUrl=False):
    """Return JSON from API."""
    url = urljoin(base, path)
    if retUrl:
        return url
    # print(f"Fetching: {url}")
    r = requests.get(url)
    rj = r.json()
    if "status" in rj and rj["status"]=="Not Found":
        return {}
    return r.json()


def convert_date_range(date_range_str):
    """Convert date of from `19 - 22 JAN 2023` to date range."""
    r = parse("{start_day} - {end_day} {month} {year}", date_range_str)
    start_date = pd.to_datetime(
        f"{r['start_day']} {r['month']} {r['year']}", format="%d %b %Y"
    )
    end_date = pd.to_datetime(
        f"{r['end_day']} {r['month']} {r['year']}", format="%d %b %Y"
    )
    return pd.date_range(start=start_date, end=end_date)


def timeify(df, col, typ=None):
    """Convert a column  to a datetime inplace."""
    if typ == "daterange":
        df[col] = df[col].apply(convert_date_range)
    else:
        df[col] = pd.to_datetime(df[col].astype(int), unit="ms")


def tablify(json_data, subcolkey=None):
    """Generate table from separate colnames/values JSON."""
    # Note that the JSON may be a few rows short cf. provided keys
    if subcolkey is None:
        results = []
        for values in json_data["values"]:
            result_dict = {}
            # Zip keys and values, filling None for missing values
            zipped_values = zip_longest(json_data["fields"], values, fillvalue=None)
            # Convert the zipped values to a dictionary and update the result_dict
            result_dict.update(dict(zipped_values))
            results.append(result_dict)
        return pd.DataFrame(results)
    else:
        df = pd.DataFrame(columns=json_data["fields"])
        for value in json_data["values"]:
            _df = pd.DataFrame(value[subcolkey])
            if len(_df.columns) < len(json_data["fields"]):
                _df[[json_data["fields"][len(_df.columns) :]]] = None
            _df.columns = json_data["fields"]
            for c in [k for k in value.keys() if k != subcolkey]:
                _df[c] = value[c]
                df = pd.concat([df, _df])
        return df

def stage_id_annotations(df, eventId=None, rallyId=None, stageId=None):
    if "eventId" not in df.columns:
        df["eventId"] = eventId
    if "rallyId" not in df.columns:
        df["rallyId"] = rallyId
    if "stageId" not in df.columns:
        df["stageId"] = stageId

# %% [markdown]
# ## Season Calendar
#
# The API call `https://api.wrc.com/content/filters/calendar` gives a list of current or latest (last, if season's end) events, from which we can get a season identifer. For the 2023 WRC championship, the season ID is `20`

# %%
"""
https://www.wrc.com/live-timing?liveTimingMenu=overall_livetiming&stage=FINAL&championshipId=249
<div id="dropdown" style="max-height: 92.25px;">
<div data-key="245" class="sc-dVhcbM hzWUOI">ALL</div>
<div data-key="247" class="sc-dVhcbM hzWUOI">WRC</div>
<div data-key="249" class="sc-dVhcbM hzWUOI" active="true">WRC2</div>
<div data-key="256" class="sc-dVhcbM hzWUOI">WRC3</div>
<div data-key="258" class="sc-dVhcbM hzWUOI">Junior WRC</div>
<div data-key="251" class="sc-dVhcbM hzWUOI">WRC2 Challenger</div>
<div data-key="254" class="sc-dVhcbM hzWUOI">Master Cup</div></div>

"""

championshipIds = {"all": 245,
                   "wrc": 247,
                   "wrc2": 249,
                   "wrc3": 256,
                   "jwrc": 258,
                   "wrc2c": 251,
                   "mcup": 254}

championshipId = championshipIds["wrc"]

# %%
stub = f"filters/calendar?language=en&size=20&championship=wrc&origin=vcms&year=2024"
json_data = _WRC_json(stub)
keys_to_keep = ['id', 'guid', 'title', 'location', 'startDate', 'endDate', 'eventId',
       'rallyId', 'description', 'round', 'cvpSeriesLink', 'sponsor', 'images',
       'season', 'competition', 'country', 'asset', '__typename', 'type',
       'uid', 'seriesUid', 'releaseYear', 'availableOn', 'availableTill',
       'startDateLocal', 'endDateLocal', 'finishDate', 'championship',
       'championshipLogo'
]
filtered_data = [
    {key: item[key] for key in keys_to_keep if key in item}
    for item in json_data["content"]
]

pd.DataFrame(filtered_data)
# Out:
#       id         guid                           title  \
# 0   C87D  WRC_2024_01              Rallye Monte-Carlo
# 1   ANhw  WRC_2024_02               WRC Rally Sweden
# 2   tv2t  WRC_2024_03          WRC Safari Rally Kenya
# 3   JCpO  WRC_2024_04               WRC Croatia Rally
# 4   lLrv  WRC_2024_05  WRC Vodafone Rally de Portugal
# 5   5VRr  WRC_2024_06       WRC Rally Italia Sardegna
# 6   htOR  WRC_2024_07     WRC ORLEN 80th Rally Poland
# 7   228Z  WRC_2024_08            WRC Tet Rally Latvia
# 8   Dv15  WRC_2024_09         WRC Secto Rally Finland
# 9   csx1  WRC_2024_10  WRC EKO Acropolis Rally Greece
# 10  D8sQ  WRC_2024_11         WRC Rally Chile Bio Bío
# 11  I8c3  WRC_2024_12      WRC Central European Rally
# 12  G6SR  WRC_2024_13          WRC FORUM8 Rally Japan
#
#                          location      startDate        endDate eventId  \
# 0                          Monaco  1706110200000  1706454000000     446
# 1                          sweden  1707984000000  1708268400000     447
# 2                 Naivasha, Kenya  1711522800000  1711890000000     448
# 3   Zagreb, City of Zagreb Region  1713423600000  1713708000000     449
# 4               Matosinhos, Porto  1715238000000  1715522400000     450
# 5                 Olbia, Sardinia  1717087500000  1717329600000     452
# 6                          Poland  1719475200000  1719756000000     453
# 7                 Liepāja, Latvia  1721277060000  1721566800000     454
# 8                       Jyväskylä  1722441600000  1722772800000     455
# 9                           Lamia  1725516060000  1725796800000     456
# 10                     Concepcion  1727350260000  1727632800000     457
# 11         Bad Griesbach, Bavaria  1729150200000  1729431000000     458
# 12                         Nagoya  1732147200000  1732431600000     459
#
#    rallyId                                        description  round  ...  \
# 0      477  The most unpredictable rally of the year. Rela...      1  ...
# 1      478  The WRC’s ultimate winter challenge. Watch in ...      2  ...
# 2      479  Held on the untamed terrains of Africa’s breat...      3  ...
# 3      480  High-speed stretches meet challenging hairpin ...      4  ...
# 4      481  Fast but technical gravel roads inland from Po...      5  ...
# 5      483  Don’t let the picturesque Mediterranean backdr...      6  ...
# 6      484  Back on the WRC calendar! Poland's lightning-f...      7  ...
# 7      485  WRC is thrilled to welcome a newcomer in Tet R...      8  ...
# 8      486  A mecca for rally drivers and enthusiasts alik...      9  ...
# 9      487  A legendary WRC fixture. Twisty gravel mountai...     10  ...
# 10     488  Based in Concepción, Chile's second-largest ci...     11  ...
# 11     489  Back on the WRC calendar after its' well recei...     12  ...
# 12     490  FORUM8 Rally Japan - the home of 2022 and 2023...     13  ...
#
#      uid    seriesUid releaseYear    availableOn  availableTill  \
# 0   C87D  WRC_2024_01        2024  1706110200000  1706454000000
# 1   ANhw  WRC_2024_02        2024  1707984000000  1708268400000
# 2   tv2t  WRC_2024_03        2024  1711522800000  1711890000000
# 3   JCpO  WRC_2024_04        2024  1713423600000  1713708000000
# 4   lLrv  WRC_2024_05        2024  1715238000000  1715522400000
# 5   5VRr  WRC_2024_06        2024  1717087500000  1717329600000
# 6   htOR  WRC_2024_07        2024  1719475200000  1719756000000
# 7   228Z  WRC_2024_08        2024  1721277060000  1721566800000
# 8   Dv15  WRC_2024_09        2024  1722441600000  1722772800000
# 9   csx1  WRC_2024_10        2024  1725516060000  1725796800000
# 10  D8sQ  WRC_2024_11        2024  1727350260000  1727632800000
# 11  I8c3  WRC_2024_12        2024  1729150200000  1729431000000
# 12  G6SR  WRC_2024_13        2024  1732147200000  1732431600000
#
#                startDateLocal               endDateLocal     finishDate  \
# 0   2024-01-24T16:30:00+01:00  2024-01-28T16:00:00+01:00  1706454000000
# 1   2024-02-15T09:00:00+01:00  2024-02-18T16:00:00+01:00  1708268400000
# 2   2024-03-27T10:00:00+03:00  2024-03-31T16:00:00+03:00  1711890000000
# 3   2024-04-18T09:00:00+02:00  2024-04-21T16:00:00+02:00  1713708000000
# 4   2024-05-09T08:00:00+01:00  2024-05-12T15:00:00+01:00  1715522400000
# 5   2024-05-30T18:45:00+02:00  2024-06-02T14:00:00+02:00  1717329600000
# 6   2024-06-27T10:00:00+02:00  2024-06-30T16:00:00+02:00  1719756000000
# 7   2024-07-18T07:31:00+03:00  2024-07-21T16:00:00+03:00  1721566800000
# 8   2024-07-31T19:00:00+03:00  2024-08-04T15:00:00+03:00  1722772800000
# 9   2024-09-05T09:01:00+03:00  2024-09-08T15:00:00+03:00  1725796800000
# 10  2024-09-26T08:31:00-03:00  2024-09-29T15:00:00-03:00  1727632800000
# 11  2024-10-17T09:30:00+02:00  2024-10-20T15:30:00+02:00  1729431000000
# 12  2024-11-21T09:00:00+09:00  2024-11-24T16:00:00+09:00  1732431600000
#
#    championship                                   championshipLogo
# 0           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 1           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 2           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 3           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 4           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 5           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 6           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 7           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 8           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 9           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 10          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 11          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 12          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
#
# [13 rows x 29 columns]

# %%
def getFullCalendar(year=CURRENT_YEAR, championship="wrc", size=20):
    stub = f"filters/calendar?language=en&size={size}&championship={championship}&origin=vcms&year={year}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.dataFrame()
    # return json_data
    return pd.DataFrame(json_data["content"])


df_fullcal = getFullCalendar()
df_fullcal.head()
# Out:
#      id         guid                           title  \
# 0  IQXg  WRC_2023_01              Rallye Monte-Carlo
# 1  lGzi  WRC_2023_02               WRC Rally Sweden
# 2  siDN  WRC_2023_03     WRC Guanajuato Rally México
# 3  rejA  WRC_2023_04               WRC Croatia Rally
# 4  9xIl  WRC_2023_05  WRC Vodafone Rally de Portugal
#
#                         location      startDate        endDate eventId  \
# 0                         Monaco  1674125280000  1674384480000     353
# 1                           Umea  1675940100000  1676199300000     354
# 2               Leon, Guanajuato  1678949100000  1679208300000     355
# 3  Zagreb, City of Zagreb Region  1682059680000  1682232480000     356
# 4              Matosinhos, Porto  1683870600000  1684043400000     357
#
#   rallyId                                        description  round  ...  \
# 0     357  The most unpredictable rally of the year. Rela...      1  ...
# 1     358  The WRC’s ultimate winter challenge. Watch in ...      2  ...
# 2     359  A thrilling ride through the colourful landsca...      3  ...
# 3     360  High-speed stretches meet challenging hairpin ...      4  ...
# 4     361  Fast but technical gravel roads inland from Po...      5  ...
#
#     uid    seriesUid releaseYear    availableOn  availableTill  \
# 0  IQXg  WRC_2023_01        2023  1674125280000  1674384480000
# 1  lGzi  WRC_2023_02        2023  1675940100000  1676199300000
# 2  siDN  WRC_2023_03        2023  1678949100000  1679208300000
# 3  rejA  WRC_2023_04        2023  1682059680000  1682232480000
# 4  9xIl  WRC_2023_05        2023  1683870600000  1684043400000
#
#               startDateLocal               endDateLocal     finishDate  \
# 0  2023-01-19T11:48:00+01:00  2023-01-22T11:48:00+01:00  1674384480000
# 1  2023-02-09T11:55:00+01:00  2023-02-12T11:55:00+01:00  1676199300000
# 2  2023-03-16T00:45:00-06:00  2023-03-19T00:45:00-06:00  1679208300000
# 3  2023-04-21T08:48:00+02:00  2023-04-23T08:48:00+02:00  1682232480000
# 4  2023-05-12T06:50:00+01:00  2023-05-14T06:50:00+01:00  1684043400000
#
#   championship                                   championshipLogo
# 0          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 1          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 2          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 3          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 4          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
#
# [5 rows x 29 columns]

# %%
len(df_fullcal)
# Out:
# 13

# %%
df_fullcal.columns
# Out:
# Index(['id', 'guid', 'title', 'location', 'startDate', 'endDate', 'eventId',
#        'rallyId', 'description', 'round', 'cvpSeriesLink', 'sponsor', 'images',
#        'season', 'competition', 'country', 'asset', '__typename', 'type',
#        'uid', 'seriesUid', 'releaseYear', 'availableOn', 'availableTill',
#        'startDateLocal', 'endDateLocal', 'finishDate', 'championship',
#        'championshipLogo'],
#       dtype='object')

# %%
df_fullcal
# Out:
#       id         guid                               title  \
# 0   IQXg  WRC_2023_01                  Rallye Monte-Carlo
# 1   lGzi  WRC_2023_02                   WRC Rally Sweden
# 2   siDN  WRC_2023_03         WRC Guanajuato Rally México
# 3   rejA  WRC_2023_04                   WRC Croatia Rally
# 4   9xIl  WRC_2023_05      WRC Vodafone Rally de Portugal
# 5   BTVM  WRC_2023_06           WRC Rally Italia Sardegna
# 6   vhG4  WRC_2023_07              WRC Safari Rally Kenya
# 7   38Ly  WRC_2023_08                   WRC Rally Estonia
# 8   Kf3P  WRC_2023_09  WRC Secto Automotive Rally Finland
# 9   aCfi  WRC_2023_10      WRC EKO Acropolis Rally Greece
# 10  ayMP  WRC_2023_11             WRC Rally Chile Bio Bío
# 11  dtcK  WRC_2023_12          WRC Central European Rally
# 12  k7il  WRC_2023_13              WRC FORUM8 Rally Japan
#
#                          location      startDate        endDate eventId  \
# 0                          Monaco  1674125280000  1674384480000     353
# 1                            Umea  1675940100000  1676199300000     354
# 2                Leon, Guanajuato  1678949100000  1679208300000     355
# 3   Zagreb, City of Zagreb Region  1682059680000  1682232480000     356
# 4               Matosinhos, Porto  1683870600000  1684043400000     357
# 5                 Olbia, Sardinia  1685602260000  1685861460000     358
# 6                 Naivasha, Kenya  1687416720000  1687675920000     359
# 7                           Tartu  1689836040000  1690095240000     360
# 8                       Jyväskylä  1691001000000  1691346540000     361
# 9                           Lamia  1694097840000  1694346300000     362
# 10                     Concepcion  1695898800000  1696182300000     363
# 11                Passau, Bavaria  1698242400000  1698588000000     364
# 12                         Nagoya  1700092800000  1700377260000     365
#
#    rallyId                                        description  round  ...  \
# 0      357  The most unpredictable rally of the year. Rela...      1  ...
# 1      358  The WRC’s ultimate winter challenge. Watch in ...      2  ...
# 2      359  A thrilling ride through the colourful landsca...      3  ...
# 3      360  High-speed stretches meet challenging hairpin ...      4  ...
# 4      361  Fast but technical gravel roads inland from Po...      5  ...
# 5      362  Don’t let the picturesque Mediterranean backdr...      6  ...
# 6      363  Held on the untamed terrains of Africa’s breat...      7  ...
# 7      364  Mind-bendingly fast smooth gravel stages inclu...      8  ...
# 8      365  A mecca for rally drivers and enthusiasts alik...      9  ...
# 9      366  A legendary WRC fixture. Twisty gravel mountai...     10  ...
# 10     367  Based in Concepción, Chile's second-largest ci...     11  ...
# 11     368  Brand-new for 2023. From the scenic and techni...     12  ...
# 12     369  FORUM8 Rally Japan - the home of 2022 and 2023...     13  ...
#
#      uid    seriesUid releaseYear    availableOn  availableTill  \
# 0   IQXg  WRC_2023_01        2023  1674125280000  1674384480000
# 1   lGzi  WRC_2023_02        2023  1675940100000  1676199300000
# 2   siDN  WRC_2023_03        2023  1678949100000  1679208300000
# 3   rejA  WRC_2023_04        2023  1682059680000  1682232480000
# 4   9xIl  WRC_2023_05        2023  1683870600000  1684043400000
# 5   BTVM  WRC_2023_06        2023  1685602260000  1685861460000
# 6   vhG4  WRC_2023_07        2023  1687416720000  1687675920000
# 7   38Ly  WRC_2023_08        2023  1689836040000  1690095240000
# 8   Kf3P  WRC_2023_09        2023  1691001000000  1691346540000
# 9   aCfi  WRC_2023_10        2023  1694097840000  1694346300000
# 10  ayMP  WRC_2023_11        2023  1695898800000  1696182300000
# 11  dtcK  WRC_2023_12        2023  1698242400000  1698588000000
# 12  k7il  WRC_2023_13        2023  1700092800000  1700377260000
#
#                startDateLocal               endDateLocal     finishDate  \
# 0   2023-01-19T11:48:00+01:00  2023-01-22T11:48:00+01:00  1674384480000
# 1   2023-02-09T11:55:00+01:00  2023-02-12T11:55:00+01:00  1676199300000
# 2   2023-03-16T00:45:00-06:00  2023-03-19T00:45:00-06:00  1679208300000
# 3   2023-04-21T08:48:00+02:00  2023-04-23T08:48:00+02:00  1682232480000
# 4   2023-05-12T06:50:00+01:00  2023-05-14T06:50:00+01:00  1684043400000
# 5   2023-06-01T08:51:00+02:00  2023-06-04T08:51:00+02:00  1685861460000
# 6   2023-06-22T09:52:00+03:00  2023-06-25T09:52:00+03:00  1687675920000
# 7   2023-07-20T09:54:00+03:00  2023-07-23T09:54:00+03:00  1690095240000
# 8   2023-08-02T21:30:00+03:00  2023-08-06T21:29:00+03:00  1691346540000
# 9   2023-09-07T17:44:00+03:00  2023-09-10T14:45:00+03:00  1694346300000
# 10  2023-09-28T08:00:00-03:00  2023-10-01T14:45:00-03:00  1696182300000
# 11  2023-10-25T16:00:00+02:00  2023-10-29T15:00:00+01:00  1698588000000
# 12  2023-11-16T09:00:00+09:00  2023-11-19T16:01:00+09:00  1700377260000
#
#    championship                                   championshipLogo
# 0           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 1           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 2           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 3           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 4           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 5           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 6           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 7           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 8           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 9           WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 10          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 11          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
# 12          WRC  [{'url': 'https://wrc-static.enhance.diagnal.c...
#
# [13 rows x 29 columns]

# %% [markdown]
# Let's get the `seasonId` from a season record in the `season` column:

# %%
df_fullcal["season"][0]
# Out:
# {'id': 'c0119c1c-bda7-403f-aa4d-29ae30959caa',
#  'name': None,
#  'seasonId': '20',
#  'title': '2023',
#  '__typename': 'Season'}

# %%
CURRENT_SEASON = df_fullcal["season"][0]["seasonId"]

seasonId = CURRENT_SEASON

# Check
# assert int(CURRENT_SEASON)==28 if CURRENT_YEAR==2024 else False
# And / or check the title?
# assert df_fullcal["season"][0]['title'] == '2024'

CURRENT_SEASON
# Out:
# '20'

# %%
# https://api.wrc.com/content/result/calendar?season=20&championship=wrc

def getResultsCalendar(seasonId=CURRENT_SEASON,  retUrl=False):
    """Get the WRC Calendar for a given season ID as a JSON result."""
    stub = f"result/calendar?season={seasonId}&championship=wrc"
    if retUrl:
        return stub
    json_data = _WRC_json(stub)
    df_calendar = tablify(json_data)
    #timeify(df_calendar, "date", "daterange")
    #timeify(df_calendar, "startDate")
    #timeify(df_calendar, "finishDate")
    # df_calendar.set_index("id", inplace=True)
    return df_calendar

# %%
getResultsCalendar().columns
# Out:
# Index(['id', 'rallyTitle', 'ROUND', 'rallyCountry', 'rallyCountryImage',
#        'rallyId', 'date', 'startDate', 'finishDate', 'driverId',
#        'driverCountryImage', 'driver', 'coDriverId', 'coDriverCountryImage',
#        'coDriver', 'teamId', 'teamLogo', 'teamName', 'manufacturer'],
#       dtype='object')

# %%
getResultsCalendar(retUrl=True)
# Out:
# 'result/calendar?season=20&championship=wrc'

# %%
getResultsCalendar().head()
# Out:
#      id                      rallyTitle ROUND rallyCountry rallyCountryImage  \
# 0  IQXg              Rallye Monte-Carlo     1       Monaco     Flags/MCO.png
# 1  lGzi               WRC Rally Sweden      2       Sweden     Flags/SWE.png
# 2  siDN     WRC Guanajuato Rally México     3       Mexico     Flags/MEX.png
# 3  rejA               WRC Croatia Rally     4      Croatia     Flags/HRV.png
# 4  9xIl  WRC Vodafone Rally de Portugal     5     Portugal     Flags/PRT.png
#
#   rallyId              date      startDate     finishDate  \
# 0     357  19 - 22 JAN 2023  1674125280000  1674384480000
# 1     358  09 - 12 FEB 2023  1675940100000  1676199300000
# 2     359  16 - 19 MAR 2023  1678949100000  1679208300000
# 3     360  21 - 23 APR 2023  1682059680000  1682232480000
# 4     361  12 - 14 MAY 2023  1683870600000  1684043400000
#
#                                driverId driverCountryImage           driver  \
# 0  1cf9ade6-25b5-5586-8393-eacfeb943eae      Flags/FRA.png  Sébastien OGIER
# 1  6632e7ca-34bf-55b8-9cad-d060000fa794      Flags/EST.png        Ott TÄNAK
# 2  1cf9ade6-25b5-5586-8393-eacfeb943eae      Flags/FRA.png  Sébastien OGIER
# 3  ae7329c9-79b3-5d96-886c-22cca6217764      Flags/GBR.png      Elfyn EVANS
# 4  d8e4bbea-3af2-5486-9ad5-a445aaec573e      Flags/FIN.png  Kalle ROVANPERÄ
#
#                              coDriverId coDriverCountryImage         coDriver  \
# 0  867cd58f-3fe3-5290-9cc5-b21cb41c523c        Flags/FRA.png  Vincent LANDAIS
# 1  00a8a5c3-f7ba-5086-86df-1a59b7da7e26        Flags/EST.png  Martin JÄRVEOJA
# 2  867cd58f-3fe3-5290-9cc5-b21cb41c523c        Flags/FRA.png  Vincent LANDAIS
# 3  53e56691-fe7c-5271-9dc5-8960df28b221        Flags/GBR.png     Scott MARTIN
# 4  e4dd8a3f-00e9-59f7-9871-9337af6085d7        Flags/FIN.png  Jonne HALTTUNEN
#
#                                  teamId          teamLogo  \
# 0  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
# 1  887309d0-48be-5f83-ad3e-abf2a79a64a3    Flags/ford.png
# 2  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
# 3  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
# 4  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  Flags/toyota.png
#
#                         teamName manufacturer
# 0        TOYOTA GAZOO RACING WRT       Toyota
# 1  M-SPORT FORD WORLD RALLY TEAM         Ford
# 2        TOYOTA GAZOO RACING WRT       Toyota
# 3        TOYOTA GAZOO RACING WRT       Toyota
# 4        TOYOTA GAZOO RACING WRT       Toyota

# %%
getResultsCalendar().tail()
# Out:
#       id                          rallyTitle ROUND rallyCountry  \
# 8   Kf3P  WRC Secto Automotive Rally Finland     9      Finland
# 9   aCfi      WRC EKO Acropolis Rally Greece    10       Greece
# 10  ayMP             WRC Rally Chile Bio Bío    11        Chile
# 11  dtcK          WRC Central European Rally    12       Europe
# 12  k7il              WRC FORUM8 Rally Japan    13        Japan
#
#    rallyCountryImage rallyId              date      startDate     finishDate  \
# 8      Flags/FIN.png     365  02 - 06 AUG 2023  1691001000000  1691346540000
# 9      Flags/GRC.png     366  07 - 10 SEP 2023  1694097840000  1694346300000
# 10     Flags/CHL.png     367  28 - 01 OCT 2023  1695898800000  1696182300000
# 11     Flags/EUR.png     368  25 - 29 OCT 2023  1698242400000  1698588000000
# 12     Flags/JPN.png     369  16 - 19 NOV 2023  1700092800000  1700377260000
#
#                                 driverId driverCountryImage            driver  \
# 8   ae7329c9-79b3-5d96-886c-22cca6217764      Flags/GBR.png       Elfyn EVANS
# 9   d8e4bbea-3af2-5486-9ad5-a445aaec573e      Flags/FIN.png   Kalle ROVANPERÄ
# 10  6632e7ca-34bf-55b8-9cad-d060000fa794      Flags/EST.png         Ott TÄNAK
# 11  c99a2a26-bd03-5153-aaa7-684d3acb5491      Flags/BEL.png  Thierry NEUVILLE
# 12  ae7329c9-79b3-5d96-886c-22cca6217764      Flags/GBR.png       Elfyn EVANS
#
#                               coDriverId coDriverCountryImage  \
# 8   53e56691-fe7c-5271-9dc5-8960df28b221        Flags/GBR.png
# 9   e4dd8a3f-00e9-59f7-9871-9337af6085d7        Flags/FIN.png
# 10  00a8a5c3-f7ba-5086-86df-1a59b7da7e26        Flags/EST.png
# 11  b1b98699-0332-528a-8a80-11eb538f1ded        Flags/BEL.png
# 12  53e56691-fe7c-5271-9dc5-8960df28b221        Flags/GBR.png
#
#             coDriver                                teamId           teamLogo  \
# 8       Scott MARTIN  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6   Flags/toyota.png
# 9    Jonne HALTTUNEN  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6   Flags/toyota.png
# 10   Martin JÄRVEOJA  887309d0-48be-5f83-ad3e-abf2a79a64a3     Flags/ford.png
# 11  Martijn WYDAEGHE  b6692ea5-df92-5cad-a91c-20319a6fffd7  Flags/hyundai.png
# 12      Scott MARTIN  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6   Flags/toyota.png
#
#                                 teamName manufacturer
# 8                TOYOTA GAZOO RACING WRT       Toyota
# 9                TOYOTA GAZOO RACING WRT       Toyota
# 10         M-SPORT FORD WORLD RALLY TEAM         Ford
# 11  HYUNDAI SHELL MOBIS WORLD RALLY TEAM      Hyundai
# 12               TOYOTA GAZOO RACING WRT       Toyota

# %%
import datetime

def timeNow(typ="ms"):
    now = int(datetime.datetime.now().timestamp())
    if typ=="ms":
        now *=1000
    return now

timeNow()
# Out:
# 1732733153000

# %%
eventId, rallyId = df_fullcal[df_fullcal["startDate"] < timeNow()].iloc[-1][
    ["eventId", "rallyId"]
]
eventId, rallyId
# Out:
# ('365', '369')

# %%
## Stages


def getStageDetails(eventId, rallyId):
    stub = f"result/stages?eventId={eventId}&rallyId={rallyId}&championship=wrc"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.dataFrame()
    df_stageDetails = tablify(json_data)
    return df_stageDetails


df_stageDetails = getStageDetails(eventId, rallyId)
df_stageDetails.head(3)
# Out:
#                                      id STAGE                   STAGE TYPE  \
# 0  ee55daa1-fd07-574f-835a-f39008081b95   SHD                    shakedown
# 1  3cd7a38a-436f-5c21-b966-8b4743f20a57   SS1  HeadToHeadSuperSpecialStage
# 2  7ae2243b-6746-516b-895e-16b5d0a2ed51   SS2                 SpecialStage
#
#   stageId eventId       STATUS       day                              name  \
# 0     SHD     365     Complete                                   Shakedown
# 1    6119     365    Completed  Thursday  SS1 TOYOTA STADIUM SSS 1 (2.1km)
# 2    6120     365  Interrupted    Friday  SS2 Isegami's Tunnel 1 (23.67km)
#
#   distance
# 0
# 1      2.1
# 2    23.67

# %%
df_stageDetails.tail()
# Out:
#                                       id  STAGE      STAGE TYPE stageId  \
# 19  9529ae88-0d8e-5449-abf9-5e7d43935cc9   SS19    SpecialStage    6137
# 20  128c0d05-4538-536f-a7d2-f929836d1dc4   SS20    SpecialStage    6138
# 21  a9e4c371-57ba-5c72-8fff-8b92a95baa60   SS21    SpecialStage    6139
# 22  4a0db031-0143-5756-af1f-e87945227001   SS22      PowerStage    6140
# 23  f8f13d04-bbaf-58d1-906d-c2d459999c1b  FINAL  overall result   FINAL
#
#    eventId     STATUS     day                                           name  \
# 19     365  Completed  Sunday                  SS19 Nenoue Kougen 1 (11.6km)
# 20     365  Completed  Sunday                      SS20 Ena City 2 (22.92km)
# 21     365  Completed  Sunday                  SS21 Nenoue Kougen 2 (11.6km)
# 22     365  Completed  Sunday  SS22 Wolf Power Stage Asahi Kougen 2 (7.52km)
# 23     365  Completed                                           Final Result
#
#    distance
# 19     11.6
# 20    22.92
# 21     11.6
# 22     7.52
# 23

# %%
def getOverall(eventId, rallyId, stageId, championship="wrc", group="all"):
    stub = f"result/stageResult?eventId={eventId}&rallyId={rallyId}&stageId={stageId}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_overall = tablify(json_data)
    stage_id_annotations(df_overall, eventId, rallyId, stageId)
    if group=="all":
        return df_overall
    else:
        return df_overall[df_overall["groupClass"]==group]

stageId = df_stageDetails[df_stageDetails["stageId"]!="FINAL"].iloc[-1]["stageId"]

getOverall(eventId, rallyId, stageId)#.head(3)
# Out:
#                                       id pos carNo  \
# 0   79c1931c-0cab-5b80-bdaa-d8674c15997e   1   #33
# 1   c58f0ad5-6dc9-5f3a-ab24-6d3306c89e06   2   #17
# 2   dee62ffc-9830-5564-97fd-b85d47ce61d2   3   #69
# 3   f2f3da23-d724-52a9-bd01-362e0e389e81   4    #4
# 4   4965f409-4d74-52b2-9a6b-c97db36bd1e7   5   #18
# 5   e3b0a0d6-ffcd-597d-8810-c9cc5e31cc13   6    #8
# 6   a0977e64-2959-5722-8be1-ab4ea8573a75   7   #20
# 7   795c4177-f68a-57a3-ad17-d4d2851e1dbe   8   #21
# 8   c70c9ad6-e0bc-5ed7-a339-c2ace0b02885   9   #22
# 9   816f6cfd-592c-5b25-88a6-516a7b851c68  10   #35
# 10  3b1728fc-e8f6-5ae0-bdbf-56d50a7c793d  11   #26
# 11  3ce34efb-f423-53b3-b42c-23c03bbacba8  12   #25
# 12  f0e87af5-0cfa-5c94-a792-6106abeacde9  13   #11
# 13  0408b743-aadc-5d1e-8bbb-964f005ebf64  14   #28
# 14  000d53cc-9e41-513d-9bb8-8044e8d099a8  15   #36
# 15  28dda2bb-c6d0-5d89-8908-189ad647bc84  16   #39
# 16  89cbef35-28bc-51e7-96c1-66b1c74f7f1c  17   #40
# 17  759b2363-6e10-5f51-a0dd-e31c074fc59d  18   #29
# 18  0576b400-4728-576e-858a-33606fd8a33e  19   #41
# 19  53fee654-84af-5e21-972e-066be3cbe2b7  20   #44
# 20  894b26d9-5a84-5861-9c8a-2459d3c84001  21   #37
# 21  c1b107e3-d79d-55b4-8cfc-4188ea8ae66d  22   #31
# 22  7113c061-23ce-5931-a074-811b78496f09  23   #49
# 23  9901ae74-d1cd-5b3c-91a1-6a63c2b45a91  24   #30
# 24  7a521bae-3d60-5a3b-b073-3d1ad3c16b12  25   #38
# 25  fadf46a9-397a-51c6-b92a-2c0300c24179  26   #46
# 26  b80b384e-5bd5-5ef3-b572-3611022ac6c4  27   #45
# 27  438d0cd1-816a-579c-9a10-a65313b83d37  28   #48
#
#                                 driverId  \
# 0   ae7329c9-79b3-5d96-886c-22cca6217764
# 1   1cf9ade6-25b5-5586-8393-eacfeb943eae
# 2   d8e4bbea-3af2-5486-9ad5-a445aaec573e
# 3   916f5b10-fee9-5b4c-b17b-6fbbc343cc3c
# 4   298f93b1-b0ef-5af4-9f0c-e468d29abfd2
# 5   6632e7ca-34bf-55b8-9cad-d060000fa794
# 6   093f0b06-7a05-5353-92ac-f5a68ae51f41
# 7   199a29d0-97f5-530f-9a5d-7ab45b1da0cc
# 8   cede2cae-3446-54d8-b9d7-7e65651ebfd1
# 9   e00988f4-2f7f-55f1-8ec6-a0e790578911
# 10  77222f77-61d8-5908-9632-24abf8556af7
# 11  209ebf34-4d0f-528b-83a2-46c38ceb499d
# 12  c99a2a26-bd03-5153-aaa7-684d3acb5491
# 13  15aa0c7e-8fbd-5923-9b70-41d012e8838d
# 14  0a4d6b0a-f926-56f3-aca2-049f93add127
# 15  c9cdcbc6-fd62-5aae-8f41-82a1c8ae2f69
# 16  5fe3cdf8-1caa-507e-a25c-f356e3271f4f
# 17  079fcb03-b8a5-5fd6-af92-6ba473b88aa3
# 18  53f655b1-91e6-5163-adad-f8e7e4c6a77b
# 19  a2406c6d-9a44-504b-b93e-488a2c733b46
# 20  754eb36a-2133-5312-b59a-f6b470c8dc54
# 21  b3ad32a3-6975-5ee7-acf2-3c5370ccf5b4
# 22  9dbcb6d2-df46-5fa8-b75d-fdf59c9b75cc
# 23  b487d175-4d7a-563c-bf10-8ec3dc5f0bc3
# 24  28c1d624-1370-564a-b156-d8bf093dc22f
# 25  e2464489-5926-5ac0-94a3-bdbf823bb827
# 26  3ab588df-cc06-5017-8ba6-143de81a5972
# 27  4f12d0bb-2cbd-586a-86df-0844b79ef0d3
#
#                                         driverCountry driverCountryImage  \
# 0   United Kingdom of Great Britain and Northern I...      Flags/GBR.png
# 1                                              France      Flags/FRA.png
# 2                                             Finland      Flags/FIN.png
# 3                                             Finland      Flags/FIN.png
# 4                                               Japan      Flags/JPN.png
# 5                                             Estonia      Flags/EST.png
# 6                                              Norway      Flags/NOR.png
# 7                                                 ANA      Flags/ANA.png
# 8                                              Poland      Flags/POL.png
# 9                                               Japan      Flags/JPN.png
# 10                                              Japan      Flags/JPN.png
# 11                                             Poland      Flags/POL.png
# 12                                            Belgium      Flags/BEL.png
# 13                                            Ireland      Flags/IRL.png
# 14                                              Japan      Flags/JPN.png
# 15                                              Japan      Flags/JPN.png
# 16                                              Japan      Flags/JPN.png
# 17                                              Spain      Flags/ESP.png
# 18                                              Japan      Flags/JPN.png
# 19                                              Japan      Flags/JPN.png
# 20                                              Japan      Flags/JPN.png
# 21                                             Canada      Flags/CAN.png
# 22                                              Japan      Flags/JPN.png
# 23                                              Japan      Flags/JPN.png
# 24                                              Japan      Flags/JPN.png
# 25                                              Japan      Flags/JPN.png
# 26                                              Japan      Flags/JPN.png
# 27                                              Japan      Flags/JPN.png
#
#                   driver                            coDriverId  \
# 0            Elfyn EVANS  53e56691-fe7c-5271-9dc5-8960df28b221
# 1        Sébastien OGIER  867cd58f-3fe3-5290-9cc5-b21cb41c523c
# 2        Kalle ROVANPERÄ  e4dd8a3f-00e9-59f7-9871-9337af6085d7
# 3         Esapekka LAPPI  2ef28d31-4a74-5794-b720-12c327c941b6
# 4       Takamoto KATSUTA  6347a621-eade-5fff-a7b4-7c4b73651e8a
# 5              Ott TÄNAK  00a8a5c3-f7ba-5086-86df-1a59b7da7e26
# 6      Andreas MIKKELSEN  5d0fb669-fb61-5d51-805b-d09c1ac7e36a
# 7        Nikolay GRYAZIN  7d63ec40-0bb6-5da3-954e-846a2d40a9a1
# 8   Kajetan KAJETANOWICZ  a488aa5c-affc-5f48-a95e-0f400495fd71
# 9            Hiroki ARAI  4f879f5d-2cce-5127-bf65-eb4034aee5f6
# 10        Osamu FUKUNAGA  037327bb-b1e5-5db9-9f35-97747020724c
# 11         Daniel CHWIST  ff1f11ca-f1dd-5b29-a16d-0af9510aa46c
# 12      Thierry NEUVILLE  b1b98699-0332-528a-8a80-11eb538f1ded
# 13         Eamonn BOLAND  a8a99c77-b74a-592e-852b-aebea61cc30c
# 14      Tomoyuki SHINKAI  8e4b14a8-433b-5001-b586-0f5cf15edf1f
# 15        Kohsuke MURATA  4bfce1b0-99ed-55e2-8e7e-a1d52f250732
# 16         Yuta YAMAMOTO  1d8f0f30-abe3-5c8e-9ac3-f9cc9be9f3a4
# 17   Miguel DÍAZ ABOITIZ  91f64ca1-c090-5d73-9e25-ba969fdf52df
# 18    Mitsuhiro KUNISAWA  b57311ff-0e08-5f28-8806-efb80bfd6356
# 19        Tohru NAKAYAMA  33c345d3-dbfe-558b-b4c6-c91c819a5117
# 20       Yasuyuki SASAKI  2e3502eb-60d4-5f14-9469-338e2327b98c
# 21          Jason BAILEY  64c84e95-2453-5d25-9309-7c7cfb8ba817
# 22        Taisuke AIHARA  5b273c48-7e5f-56c6-8890-7d6753cd88c8
# 23          Satoshi IMAI  ce5d6a41-d103-51fe-8b44-2cb3776f8831
# 24          Makoto HOTTA  3614d98b-2077-5896-a218-89d91d96c1d7
# 25     Yasunori HAGIWARA  e6f37ce0-7731-5942-996d-63cde99f1e23
# 26           Koji TAKATA  a655075d-d4b8-5790-b96c-ed6480de882c
# 27      Hiroyasu SHIMIZU  bba42333-aeba-5102-8f37-191cf8de0723
#
#                                       coDriverCountry coDriverCountryImage  \
# 0   United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 1                                              France        Flags/FRA.png
# 2                                             Finland        Flags/FIN.png
# 3                                             Finland        Flags/FIN.png
# 4                                             Ireland        Flags/IRL.png
# 5                                             Estonia        Flags/EST.png
# 6                                              Norway        Flags/NOR.png
# 7                                                 ANA        Flags/ANA.png
# 8                                              Poland        Flags/POL.png
# 9                                               Japan        Flags/JPN.png
# 10                                              Japan        Flags/JPN.png
# 11                                             Poland        Flags/POL.png
# 12                                            Belgium        Flags/BEL.png
# 13                                            Ireland        Flags/IRL.png
# 14                                              Japan        Flags/JPN.png
# 15                                              Japan        Flags/JPN.png
# 16                                              Japan        Flags/JPN.png
# 17                                              Spain        Flags/ESP.png
# 18                                              Japan        Flags/JPN.png
# 19                                              Japan        Flags/JPN.png
# 20                                              Japan        Flags/JPN.png
# 21                                             Canada        Flags/CAN.png
# 22                                              Japan        Flags/JPN.png
# 23                                        New Zealand        Flags/NZL.png
# 24                                              Japan        Flags/JPN.png
# 25                                              Japan        Flags/JPN.png
# 26                                              Japan        Flags/JPN.png
# 27                                              Japan        Flags/JPN.png
#
#     ... penaltyTime       time  totalTime   diffFirst  diffPrev groupClass  \
# 0   ...              3:32:08.8  3:32:08.8                              RC1
# 1   ...      1:00.0  3:33:26.5  3:33:26.5     +1:17.7   +1:17.7        RC1
# 2   ...              3:33:55.3  3:33:55.3     +1:46.5     +28.8        RC1
# 3   ...              3:34:59.1  3:34:59.1     +2:50.3   +1:03.8        RC1
# 4   ...      1:10.0  3:35:19.1  3:35:19.1     +3:10.3     +20.0        RC1
# 5   ...              3:35:37.1  3:35:37.1     +3:28.3     +18.0        RC1
# 6   ...              3:39:42.5  3:39:42.5     +7:33.7   +4:05.4        RC2
# 7   ...              3:40:58.4  3:40:58.4     +8:49.6   +1:15.9        RC2
# 8   ...              3:51:34.7  3:51:34.7    +19:25.9  +10:36.3        RC2
# 9   ...              3:54:31.5  3:54:31.5    +22:22.7   +2:56.8        RC4
# 10  ...              3:56:47.8  3:56:47.8    +24:39.0   +2:16.3        RC2
# 11  ...              4:00:01.8  4:00:01.8    +27:53.0   +3:14.0        RC2
# 12  ...              4:00:13.5  4:00:13.5    +28:04.7     +11.7        RC1
# 13  ...              4:00:47.4  4:00:47.4    +28:38.6     +33.9        RC2
# 14  ...        10.0  4:07:50.4  4:07:50.4    +35:41.6   +7:03.0     JRCar1
# 15  ...              4:11:57.6  4:11:57.6    +39:48.8   +4:07.2     JRCar1
# 16  ...        10.0  4:19:08.5  4:19:08.5    +46:59.7   +7:10.9     JRCar2
# 17  ...              4:32:39.2  4:32:39.2  +1:00:30.4  +13:30.7        RC2
# 18  ...              4:37:03.1  4:37:03.1  +1:04:54.3   +4:23.9        RC5
# 19  ...      1:00.0  4:42:25.1  4:42:25.1  +1:10:16.3   +5:22.0     JRCar1
# 20  ...              5:02:45.8  5:02:45.8  +1:30:37.0  +20:20.7     JRCar1
# 21  ...      3:00.0  5:03:05.7  5:03:05.7  +1:30:56.9     +19.9        RC3
# 22  ...        20.0  5:06:23.9  5:06:23.9  +1:34:15.1   +3:18.2     JRCar3
# 23  ...              5:19:31.7  5:19:31.7  +1:47:22.9  +13:07.8        RC2
# 24  ...      1:00.0  5:20:22.0  5:20:22.0  +1:48:13.2     +50.3     JRCar1
# 25  ...      5:30.0  5:23:11.4  5:23:11.4  +1:51:02.6   +2:49.4     JRCar1
# 26  ...        40.0  5:53:39.5  5:53:39.5  +2:21:30.7  +30:28.1     JRCar1
# 27  ...              5:57:43.1  5:57:43.1  +2:25:34.3   +4:03.6     JRCar3
#
#    championshipId eventId rallyId stageId
# 0            None     365     369    6140
# 1            None     365     369    6140
# 2            None     365     369    6140
# 3            None     365     369    6140
# 4            None     365     369    6140
# 5            None     365     369    6140
# 6            None     365     369    6140
# 7            None     365     369    6140
# 8            None     365     369    6140
# 9            None     365     369    6140
# 10           None     365     369    6140
# 11           None     365     369    6140
# 12           None     365     369    6140
# 13           None     365     369    6140
# 14           None     365     369    6140
# 15           None     365     369    6140
# 16           None     365     369    6140
# 17           None     365     369    6140
# 18           None     365     369    6140
# 19           None     365     369    6140
# 20           None     365     369    6140
# 21           None     365     369    6140
# 22           None     365     369    6140
# 23           None     365     369    6140
# 24           None     365     369    6140
# 25           None     365     369    6140
# 26           None     365     369    6140
# 27           None     365     369    6140
#
# [28 rows x 27 columns]

# %%
getOverall(eventId, rallyId, stageId).columns
# Out:
# Index(['id', 'pos', 'carNo', 'driverId', 'driverCountry', 'driverCountryImage',
#        'driver', 'coDriverId', 'coDriverCountry', 'coDriverCountryImage',
#        'coDriver', 'teamId', 'team/car', 'teamName', 'teamLogo', 'eligibility',
#        'stageTime', 'penaltyTime', 'time', 'totalTime', 'diffFirst',
#        'diffPrev', 'groupClass', 'championshipId', 'eventId', 'rallyId',
#        'stageId'],
#       dtype='object')

# %%
def getStageTimes(eventId, rallyId, stageId, championship="wrc"):
    stub = f"result/stageTimes?eventId={eventId}&rallyId={rallyId}&stageId={stageId}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_stageTimes = tablify(json_data)
    stage_id_annotations(df_stageTimes, eventId, rallyId, stageId)
    return df_stageTimes


getStageTimes(eventId, rallyId, stageId).head(3)
# Out:
#                                      id pos carNo  \
# 0  f0e87af5-0cfa-5c94-a792-6106abeacde9   1   #11
# 1  e3b0a0d6-ffcd-597d-8810-c9cc5e31cc13   2    #8
# 2  f2f3da23-d724-52a9-bd01-362e0e389e81   3    #4
#
#                                driverId driverCountry driverCountryImage  \
# 0  c99a2a26-bd03-5153-aaa7-684d3acb5491       Belgium      Flags/BEL.png
# 1  6632e7ca-34bf-55b8-9cad-d060000fa794       Estonia      Flags/EST.png
# 2  916f5b10-fee9-5b4c-b17b-6fbbc343cc3c       Finland      Flags/FIN.png
#
#              driver                            coDriverId coDriverCountry  \
# 0  Thierry NEUVILLE  b1b98699-0332-528a-8a80-11eb538f1ded         Belgium
# 1         Ott TÄNAK  00a8a5c3-f7ba-5086-86df-1a59b7da7e26         Estonia
# 2    Esapekka LAPPI  2ef28d31-4a74-5794-b720-12c327c941b6         Finland
#
#   coDriverCountryImage  ...              teamLogo eligibility     status  \
# 0        Flags/BEL.png  ...  teamLogo/hyundai.png           M  Completed
# 1        Flags/EST.png  ...     teamLogo/ford.png           M  Completed
# 2        Flags/FIN.png  ...  teamLogo/hyundai.png           M  Completed
#
#   stageId diffFirst diffPrev stageTime championshipId eventId rallyId
# 0    6140                       4:48.8           None     365     369
# 1    6140      +2.4     +2.4    4:51.2           None     365     369
# 2    6140      +6.8     +4.4    4:55.6           None     365     369
#
# [3 rows x 24 columns]

# %%
#getStageTimes(365, 369, 4161).head(3)

# %%
def getSplitTimes(eventId, rallyId, stageId, championship="wrc"):
    stub = f"result/splitTime?eventId={eventId}&rallyId={rallyId}&stageId={stageId}&championship={championship}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_splitTimes = tablify(json_data)
    stage_id_annotations(df_splitTimes, eventId, rallyId, stageId)
    return df_splitTimes


getSplitTimes(eventId, rallyId, stageId).head(3)
# Out:
#                                      id pos carNo  \
# 0  151574c6-4998-59df-8c23-72c6fc8fcc26   1   #26
# 1  86e4c829-8070-555e-b509-dfd5877c8550   2   #22
# 2  68ee0f32-975d-59df-812d-138d26836c90   3   #25
#
#                                driverId driverCountry driverCountryImage  \
# 0  77222f77-61d8-5908-9632-24abf8556af7         Japan      Flags/JPN.png
# 1  cede2cae-3446-54d8-b9d7-7e65651ebfd1        Poland      Flags/POL.png
# 2  209ebf34-4d0f-528b-83a2-46c38ceb499d        Poland      Flags/POL.png
#
#                  driver                            coDriverId coDriverCountry  \
# 0        Osamu FUKUNAGA  037327bb-b1e5-5db9-9f35-97747020724c           Japan
# 1  Kajetan KAJETANOWICZ  a488aa5c-affc-5f48-a95e-0f400495fd71          Poland
# 2         Daniel CHWIST  ff1f11ca-f1dd-5b29-a16d-0af9510aa46c          Poland
#
#   coDriverCountryImage  ... splitPointTimeId groupClass  \
# 0        Flags/JPN.png  ...           348824        RC2
# 1        Flags/POL.png  ...           348826        RC2
# 2        Flags/POL.png  ...           348828        RC2
#
#                        start stageTime diffFirst  round1  round2 eventId  \
# 0  2023-11-19T14:19:00+09:00    5:37.1            3:58.7  5:05.7     365
# 1  2023-11-19T14:23:00+09:00    5:18.6     -18.5   -12.4   -16.8     365
# 2  2023-11-19T14:27:00+09:00    5:40.3      +3.2    +3.1    +2.5     365
#
#   rallyId stageId
# 0     369    6140
# 1     369    6140
# 2     369    6140
#
# [3 rows x 27 columns]

# %%
getSplitTimes(eventId, rallyId, stageId).columns
# Out:
# Index(['id', 'pos', 'carNo', 'driverId', 'driverCountry', 'driverCountryImage',
#        'driver', 'coDriverId', 'coDriverCountry', 'coDriverCountryImage',
#        'coDriver', 'teamId', 'team/car', 'teamName', 'teamLogo', 'eligibility',
#        'splitPointId', 'splitPointTimeId', 'groupClass', 'start', 'stageTime',
#        'diffFirst', 'round1', 'round2', 'eventId', 'rallyId', 'stageId'],
#       dtype='object')

# %%
championshipId
# Out:
# 247

# %%
def getStageWinners(eventId, championship="wrc"):
    championshipId = championshipIds[championship]
    stub = f"result/stageWinners?eventId={eventId}&championshipId={championshipId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_stageWinners = tablify(json_data)
    return df_stageWinners


getStageWinners(eventId, ).head(3)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def getItinerary(eventId):
    stub = f"result/itinerary?eventId={eventId}&extended=true"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_itinerary = tablify(json_data, "values")
    return df_itinerary


getItinerary(eventId).tail(3)
# Out:
#     stage eventId                               stageId  distance  \
# 23   SS22     365  4a0db031-0143-5756-af1f-e87945227001   7.52 km
# 24   SF22     365  4a0db031-0143-5756-af1f-e87945227001
# 25  TC22A     365                                  null  39.46 km
#
#    timingPrecision firstCarDueDateTime      firstCarDueDateTimeMs  \
# 23          Minute               14:15  2023-11-19T14:15:00+09:00
# 24      Thousandth
# 25          Minute               16:00  2023-11-19T16:00:00+09:00
#
#    controlPenalties     status          type  \
# 23             None  Completed    StageStart
# 24             None  Completed  FlyingFinish
# 25             Late    Running   TimeControl
#
#                                             location targetDuration  \
# 23                   Wolf Power Stage Asahi Kougen 2       00:03:00
# 24                   Wolf Power Stage Asahi Kougen 2       00:00:00
# 25  FINISH - Technical Zone & Podium Holding Area IN       01:45:00
#
#    targetDurationMs      id  order                  date
# 23           180000  1095.0    4.0  Sunday 19th November
# 24                0  1095.0    4.0  Sunday 19th November
# 25          6300000  1095.0    4.0  Sunday 19th November

# %%
def getStartlist(eventId):
    stub = f"result/startLists?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_startlist = tablify(json_data, "startListItems")
    return df_startlist


getStartlist(eventId).tail(3)
# Out:
#    order         startDateTimeLocal carNo  \
# 29    30  2023-11-19T05:34:00+09:00   #45
# 30    31  2023-11-19T05:34:00+09:00   #47
# 31    32  2023-11-19T05:34:00+09:00   #48
#
#                                 driverId driverCountry driverCountryImage  \
# 29  3ab588df-cc06-5017-8ba6-143de81a5972         Japan      Flags/JPN.png
# 30  8584c859-11be-5de8-9ba1-f91976ec0b46         Japan      Flags/JPN.png
# 31  4f12d0bb-2cbd-586a-86df-0844b79ef0d3         Japan      Flags/JPN.png
#
#               driver                            coDriverId coDriverCountry  \
# 29       Koji TAKATA  a655075d-d4b8-5790-b96c-ed6480de882c           Japan
# 30      Satoshi IRIE  7336f886-56da-5a98-b9a8-fc626172e583           Japan
# 31  Hiroyasu SHIMIZU  bba42333-aeba-5102-8f37-191cf8de0723           Japan
#
#    coDriverCountryImage          coDriver  \
# 29        Flags/JPN.png  Takashi SEKIMOTO
# 30        Flags/JPN.png  Satoshi KAGEYAMA
# 31        Flags/JPN.png    Takahiro YASUI
#
#                                   teamId  team/car teamName  \
# 29  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6  GR Yaris   Toyota
# 30  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6      Vitz   Toyota
# 31  be461a0c-d1fd-5052-a69c-3fd94f8cf5f6     Yaris   Toyota
#
#                teamLogo eligibility groupClass priority  \
# 29  teamLogo/toyota.png                 JRCar1     None
# 30  teamLogo/toyota.png                 JRCar3     None
# 31  teamLogo/toyota.png                 JRCar3     None
#
#                                       id               date
# 29  d5126c53-c54e-514f-8b16-16ff6b9b1050  Sunday 2023-11-19
# 30  d5126c53-c54e-514f-8b16-16ff6b9b1050  Sunday 2023-11-19
# 31  d5126c53-c54e-514f-8b16-16ff6b9b1050  Sunday 2023-11-19

# %%
def getPenalties(eventId):
    stub = f"result/penalty?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_penalties = tablify(json_data)
    return df_penalties


getPenalties(eventId).head(3)
# Out:
#      id carNo                              driverId driverCountry  \
# 0  4844   #46  e2464489-5926-5ac0-94a3-bdbf823bb827         Japan
# 1  4845   #34  d6030311-c622-5262-8a0e-8fb4e30bcc29         Japan
# 2  4846   #34  d6030311-c622-5262-8a0e-8fb4e30bcc29         Japan
#
#   driverCountryImage             driver                            coDriverId  \
# 0      Flags/JPN.png  Yasunori HAGIWARA  e6f37ce0-7731-5942-996d-63cde99f1e23
# 1      Flags/JPN.png         Toshi ARAI  05b11bf7-a75c-53e7-87eb-9ea080333b1c
# 2      Flags/JPN.png         Toshi ARAI  05b11bf7-a75c-53e7-87eb-9ea080333b1c
#
#   coDriverCountry coDriverCountryImage          coDriver  ... eligibility  \
# 0           Japan        Flags/JPN.png     Koichi HARADA  ...
# 1           Japan        Flags/JPN.png  Yuichi MATSUMOTO  ...
# 2           Japan        Flags/JPN.png  Yuichi MATSUMOTO  ...
#
#   groupClass rallyId entryId controlId penaltyTime penaltyDuration  \
# 0     JRCar1     369   47504     25793        40.0           PT40S
# 1     JRCar1     369   47494     25765        10.0           PT10S
# 2     JRCar1     369   47494     25765        10.0           PT10S
#
#   penaltyDurationMs       reason control
# 0             40000  4 MINS LATE     TC1
# 1             10000   1 MIN LATE    TC1D
# 2             10000   1 MIN LATE    TC1D
#
# [3 rows x 24 columns]

# %%
def getRetirements(eventId):
    stub = f"result/retirements?eventId={eventId}"
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_retirements = tablify(json_data)
    return df_retirements


getRetirements(eventId).head(3)
# Out:
#      id carNo                              driverId driverCountry  \
# 0  8817   #44  0a4d6b0a-f926-56f3-aca2-049f93add127         Japan
# 1  8818   #51  53f655b1-91e6-5163-adad-f8e7e4c6a77b         Japan
# 2  8819   #38  b487d175-4d7a-563c-bf10-8ec3dc5f0bc3         Japan
#
#   driverCountryImage              driver  \
# 0      Flags/JPN.png    Tomoyuki SHINKAI
# 1      Flags/JPN.png  Mitsuhiro KUNISAWA
# 2      Flags/JPN.png        Satoshi IMAI
#
#                              coDriverId coDriverCountry coDriverCountryImage  \
# 0  8e4b14a8-433b-5001-b586-0f5cf15edf1f           Japan        Flags/JPN.png
# 1  b57311ff-0e08-5f28-8806-efb80bfd6356           Japan        Flags/JPN.png
# 2  ce5d6a41-d103-51fe-8b44-2cb3776f8831     New Zealand        Flags/NZL.png
#
#           coDriver  ...      team/car teamName              teamLogo  \
# 0      Yuichi ANDO  ...      GR Yaris   Toyota   teamLogo/toyota.png
# 1  Masahiko KIHARA  ...  Clio RS Line  Renault  teamLogo/renault.png
# 2     Jason FARMER  ...            C3  Citroen  teamLogo/citroen.png
#
#      eligibility groupClass rallyId entryId controlId      reason control
# 0                       JR1     490   54575     34603  MECHANICAL     TC2
# 1                       RC5     490   54582     34605  MECHANICAL     SF2
# 2  WRC2 (DCM/CC)        RC2     490   54570     34608    ACCIDENT     SF3
#
# [3 rows x 21 columns]

# %%
def getChampionship(
    seasonId, eventId, championship_type="driver", championship="all", retUrl=False
):
    """ championship_tpe: driver | codriver | manufacturer"""
    championshipId = championshipIds[championship]
    stub = f"result/championshipresult?seasonId={seasonId}&championshipId={championshipId}&type={championship_type}&championship={championship}"
    if retUrl:
        return stub
    json_data = _WRC_json(stub)
    if not json_data:
        return pd.DataFrame()
    df_splitTimes = tablify(json_data)
    return df_splitTimes


championship_type = "driver"  # where is list?

getChampionship(seasonId, championship_type).head(3)
# Out:
#   championshipEntryId overallPosition overallPoints            driver  \
# 0                5144               1           242  Thierry NEUVILLE
# 1                5146               2           210       Elfyn EVANS
# 2                5147               3           200         Ott TÄNAK
#
#   driverCountryImage                              driverId tyreManufacturer  \
# 0      Flags/BEL.png  c99a2a26-bd03-5153-aaa7-684d3acb5491             None
# 1      Flags/GBR.png  ae7329c9-79b3-5d96-886c-22cca6217764             None
# 2      Flags/EST.png  6632e7ca-34bf-55b8-9cad-d060000fa794             None
#
#   teamName              teamLogo _contry_iso_MCO  ...  \
# 0  Hyundai  teamLogo/hyundai.png                  ...
# 1   Toyota   teamLogo/toyota.png                  ...
# 2  Hyundai  teamLogo/hyundai.png                  ...
#
#   pointsBreakDown_contry_iso_EUR position_contry_iso_EUR  \
# 0                     13 + 3 + 2                     (3)
# 1                     15 + 6 + 3                     (2)
# 2                         18 + 4                     (1)
#
#   status_contry_iso_EUR totalPoints_contry_iso_EUR _contry_iso_JPN  \
# 0              Finished                         18
# 1              Finished                         24
# 2              Finished                         22
#
#   dropped_contry_iso_JPN pointsBreakDown_contry_iso_JPN  \
# 0                  false                      6 + 7 + 4
# 1                  false                     18 + 4 + 3
# 2                  false                              R
#
#   position_contry_iso_JPN status_contry_iso_JPN totalPoints_contry_iso_JPN
# 0                     (6)              Finished                         17
# 1                     (1)              Finished                         25
# 2                     (R)       RetiredAccident                          0
#
# [3 rows x 87 columns]

# %%
getChampionship(seasonId, eventId, championship_type)
#championshipresult?seasonId=28&championshipId=245&type=driver&championship=wrc
# Out:
#    championshipEntryId overallPosition overallPoints                driver  \
# 0                 5144               1           242      Thierry NEUVILLE
# 1                 5146               2           210           Elfyn EVANS
# 2                 5147               3           200             Ott TÄNAK
# 3                 5145               4           191       Sébastien OGIER
# 4                 5148               5           162       Adrien FOURMAUX
# 5                 5150               6           116      Takamoto KATSUTA
# 6                 5273               7           114       Kalle ROVANPERÄ
# 7                 5154               8            46      Grégoire MUNSTER
# 8                 5870               9            44          Daniel SORDO
# 9                 5276              10            44           Sami PAJARI
# 10                5149              11            40     Andreas MIKKELSEN
# 11                5271              12            33        Esapekka LAPPI
# 12                5275              13            27        Oliver SOLBERG
# 13                5151              14            24       Nikolay GRYAZIN
# 14                6156              15            22         Martins SESKS
# 15                5153              16            14          Yohan ROSSEL
# 16                5480              17             9  Kajetan KAJETANOWICZ
# 17                5479              18             8        Gus GREENSMITH
# 18                6469              19             7         Robert VIRVES
# 19                5277              20             7        Georg LINNAMÄE
# 20                6330              21             6    Jari-Matti LATVALA
# 21                5871              22             6            Jan SOLANS
# 22                5280              23             5           Lauri JOONA
# 23                5279              24             4        Mikko HEIKKILÄ
# 24                5278              25             3        Roope KORHONEN
# 25                6590              26             3           Filip MARES
# 26                6591              27             2          Miko MARCZYK
# 27                6623              28             2           Hiroki ARAI
# 28                5481              29             2    Jourdan SERDERIDIS
# 29                5872              30             2       Joshua MCERLEAN
# 30                5152              31             2            Pepe LÓPEZ
# 31                6470              32             1     Fabrizio ZALDIVAR
# 32                6022              33             1         Martin PROKOP
# 33                5281              34             0      Lorenzo BERTELLI
# 34                6624              35             0     Heikki KOVALAINEN
#
#    driverCountryImage                              driverId tyreManufacturer  \
# 0       Flags/BEL.png  c99a2a26-bd03-5153-aaa7-684d3acb5491             None
# 1       Flags/GBR.png  ae7329c9-79b3-5d96-886c-22cca6217764             None
# 2       Flags/EST.png  6632e7ca-34bf-55b8-9cad-d060000fa794             None
# 3       Flags/FRA.png  1cf9ade6-25b5-5586-8393-eacfeb943eae             None
# 4       Flags/FRA.png  bf956e8a-5cad-5327-add0-26e0481ea508             None
# 5       Flags/JPN.png  298f93b1-b0ef-5af4-9f0c-e468d29abfd2             None
# 6       Flags/FIN.png  d8e4bbea-3af2-5486-9ad5-a445aaec573e             None
# 7       Flags/LUX.png  c718f17c-f6a0-54b5-bad9-a406b8cc95f0             None
# 8       Flags/ESP.png  d06b6c54-863a-533d-9241-9dd04f7acb85             None
# 9       Flags/FIN.png  caeac19e-6be8-509e-882a-28ff3a15af6a             None
# 10      Flags/NOR.png  093f0b06-7a05-5353-92ac-f5a68ae51f41             None
# 11      Flags/FIN.png  916f5b10-fee9-5b4c-b17b-6fbbc343cc3c             None
# 12      Flags/SWE.png  208c95e1-d9ff-5633-8ae5-390568868a39             None
# 13      Flags/BGR.png  ffedfbf6-eea2-5322-abaf-61c1950f955b             None
# 14      Flags/LVA.png  fe85b11f-b29a-53cf-aca9-eaaa02597286             None
# 15      Flags/FRA.png  5e88e4b8-50a7-5437-ba3d-e61eb9a34c0a             None
# 16      Flags/POL.png  cede2cae-3446-54d8-b9d7-7e65651ebfd1             None
# 17      Flags/GBR.png  3f4ed2f1-010b-576e-991f-61416a6515fd             None
# 18      Flags/EST.png  33abc324-e795-508b-9151-9b175ffb198b             None
# 19      Flags/EST.png  c5aa09e5-f000-5339-bbb3-eed2b4343318             None
# 20      Flags/FIN.png  d5155d04-3a8e-5fff-a438-5a64df15a176             None
# 21      Flags/ESP.png  311d1923-5215-50b4-b61f-c933bbd248fd             None
# 22      Flags/FIN.png  93a90a6e-caff-5d41-87ef-f30f4a9b1b8a             None
# 23      Flags/FIN.png  a5cd3c11-d6ee-5a35-8459-424ad4b10ee3             None
# 24      Flags/FIN.png  bac804d1-0b28-574f-81a6-16ae6f98ebc8             None
# 25      Flags/CZE.png  8df70f85-9674-5d40-b83d-0fbcdf43a794             None
# 26      Flags/POL.png  0afa8337-da17-5610-93c6-b9962c32f645             None
# 27      Flags/JPN.png  e00988f4-2f7f-55f1-8ec6-a0e790578911             None
# 28      Flags/GRC.png  2c4a2657-2915-5d47-9e3f-7a083d60e499             None
# 29      Flags/IRL.png  053c8f07-778e-50f3-9ff7-cbf758aa799f             None
# 30      Flags/ESP.png  e2312d93-43d7-573b-adcf-0ae268209ddb             None
# 31      Flags/PRY.png  a593deb7-30b2-558f-9742-584dcae2b6b8             None
# 32      Flags/CZE.png  5a879155-f08a-5a14-a361-2521d6fc9a79             None
# 33      Flags/ITA.png  66c4d1ec-6dad-5b70-b3bb-7c5132e479ca             None
# 34      Flags/FIN.png  502b2eea-ba2b-5497-8974-3526eec20681             None
#
#    teamName              teamLogo _contry_iso_MCO  ...  \
# 0   Hyundai  teamLogo/hyundai.png                  ...
# 1    Toyota   teamLogo/toyota.png                  ...
# 2   Hyundai  teamLogo/hyundai.png                  ...
# 3    Toyota   teamLogo/toyota.png                  ...
# 4      Ford     teamLogo/ford.png                  ...
# 5    Toyota   teamLogo/toyota.png                  ...
# 6    Toyota   teamLogo/toyota.png                  ...
# 7      Ford     teamLogo/ford.png                  ...
# 8   Hyundai  teamLogo/hyundai.png                  ...
# 9    Toyota   teamLogo/toyota.png                  ...
# 10  Hyundai  teamLogo/hyundai.png                  ...
# 11  Hyundai  teamLogo/hyundai.png                  ...
# 12    Skoda    teamLogo/skoda.png                  ...
# 13  Citroen  teamLogo/citroen.png                  ...
# 14     Ford     teamLogo/ford.png                  ...
# 15  Citroen  teamLogo/citroen.png                  ...
# 16    Skoda    teamLogo/skoda.png                  ...
# 17    Skoda    teamLogo/skoda.png                  ...
# 18    Skoda    teamLogo/skoda.png                  ...
# 19   Toyota   teamLogo/toyota.png                  ...
# 20   Toyota   teamLogo/toyota.png                  ...
# 21   Toyota   teamLogo/toyota.png                  ...
# 22    Skoda    teamLogo/skoda.png                  ...
# 23   Toyota   teamLogo/toyota.png                  ...
# 24   Toyota   teamLogo/toyota.png                  ...
# 25   Toyota   teamLogo/toyota.png                  ...
# 26    Skoda    teamLogo/skoda.png                  ...
# 27    Skoda    teamLogo/skoda.png                  ...
# 28     Ford     teamLogo/ford.png                  ...
# 29    Skoda    teamLogo/skoda.png                  ...
# 30    Skoda    teamLogo/skoda.png                  ...
# 31    Skoda    teamLogo/skoda.png                  ...
# 32    Skoda    teamLogo/skoda.png                  ...
# 33   Toyota   teamLogo/toyota.png                  ...
# 34   Toyota   teamLogo/toyota.png                  ...
#
#    pointsBreakDown_contry_iso_EUR position_contry_iso_EUR  \
# 0                      13 + 3 + 2                     (3)
# 1                      15 + 6 + 3                     (2)
# 2                          18 + 4                     (1)
# 3                               R                     (R)
# 4                       0 + 5 + 1                    (32)
# 5                      10 + 7 + 5                     (4)
# 6                               -                     (-)
# 7                           8 + 2                     (5)
# 8                               -                     (-)
# 9                               R                     (R)
# 10                      0 + 0 + 4                    (31)
# 11                              -                     (-)
# 12                          4 + 1                     (7)
# 13                          6 + 0                     (6)
# 14                              -                     (-)
# 15                              -                     (-)
# 16                          1 + 0                    (10)
# 17                              -                     (-)
# 18                              -                     (-)
# 19                              -                     (-)
# 20                              -                     (-)
# 21                              -                     (-)
# 22                              -                     (-)
# 23                              -                     (-)
# 24                              -                     (-)
# 25                          3 + 0                     (8)
# 26                          2 + 0                     (9)
# 27                              -                     (-)
# 28                          0 + 0                    (20)
# 29                              -                     (-)
# 30                              -                     (-)
# 31                              -                     (-)
# 32                              -                     (-)
# 33                              -                     (-)
# 34                              -                     (-)
#
#    status_contry_iso_EUR totalPoints_contry_iso_EUR _contry_iso_JPN  \
# 0               Finished                         18
# 1               Finished                         24
# 2               Finished                         22
# 3        RetiredAccident                          0
# 4               Finished                          6
# 5               Finished                         22
# 6            DidNotEnter                          0
# 7               Finished                         10
# 8            DidNotEnter                          0
# 9        RetiredAccident                          0
# 10              Finished                          4
# 11           DidNotEnter                          0
# 12              Finished                          5
# 13              Finished                          6
# 14           DidNotEnter                          0
# 15           DidNotEnter                          0
# 16              Finished                          1
# 17           DidNotEnter                          0
# 18           DidNotEnter                          0
# 19           DidNotEnter                          0
# 20           DidNotEnter                          0
# 21           DidNotEnter                          0
# 22           DidNotEnter                          0
# 23           DidNotEnter                          0
# 24           DidNotEnter                          0
# 25              Finished                          3
# 26              Finished                          2
# 27           DidNotEnter                          0
# 28              Finished                          0
# 29           DidNotEnter                          0
# 30           DidNotEnter                          0
# 31           DidNotEnter                          0
# 32           DidNotEnter                          0
# 33           DidNotEnter                          0
# 34           DidNotEnter                          0
#
#    dropped_contry_iso_JPN pointsBreakDown_contry_iso_JPN  \
# 0                   false                      6 + 7 + 4
# 1                   false                     18 + 4 + 3
# 2                   false                              R
# 3                   false                     15 + 5 + 5
# 4                   false                         13 + 3
# 5                   false                     10 + 2 + 2
# 6                   false                              -
# 7                   false                          8 + 1
# 8                   false                              -
# 9                   false                          3 + 0
# 10                  false                      0 + 6 + 1
# 11                  false                              -
# 12                  false                              -
# 13                  false                              4
# 14                  false                              -
# 15                  false                              -
# 16                  false                              -
# 17                  false                              1
# 18                  false                              -
# 19                  false                              -
# 20                  false                              -
# 21                  false                              -
# 22                  false                              -
# 23                  false                              -
# 24                  false                              -
# 25                  false                              -
# 26                  false                              -
# 27                  false                          2 + 0
# 28                  false                              -
# 29                  false                              -
# 30                  false                              -
# 31                  false                              -
# 32                  false                              -
# 33                  false                              -
# 34                  false                              -
#
#    position_contry_iso_JPN status_contry_iso_JPN totalPoints_contry_iso_JPN
# 0                      (6)              Finished                         17
# 1                      (1)              Finished                         25
# 2                      (R)       RetiredAccident                          0
# 3                      (2)              Finished                         25
# 4                      (3)              Finished                         16
# 5                      (4)              Finished                         14
# 6                      (-)           DidNotEnter                          0
# 7                      (5)              Finished                          9
# 8                      (-)           DidNotEnter                          0
# 9                      (8)              Finished                          3
# 10                    (31)              Finished                          7
# 11                     (-)           DidNotEnter                          0
# 12                     (-)           DidNotEnter                          0
# 13                     (7)              Finished                          4
# 14                     (-)           DidNotEnter                          0
# 15                     (-)           DidNotEnter                          0
# 16                     (-)           DidNotEnter                          0
# 17                    (10)              Finished                          1
# 18                     (-)           DidNotEnter                          0
# 19                     (-)           DidNotEnter                          0
# 20                     (-)           DidNotEnter                          0
# 21                     (-)           DidNotEnter                          0
# 22                     (-)           DidNotEnter                          0
# 23                     (-)           DidNotEnter                          0
# 24                     (-)           DidNotEnter                          0
# 25                     (-)           DidNotEnter                          0
# 26                     (-)           DidNotEnter                          0
# 27                     (9)              Finished                          2
# 28                     (-)           DidNotEnter                          0
# 29                     (-)           DidNotEnter                          0
# 30                     (-)           DidNotEnter                          0
# 31                     (-)           DidNotEnter                          0
# 32                     (-)           DidNotEnter                          0
# 33                     (-)           DidNotEnter                          0
# 34                     (-)           DidNotEnter                          0
#
# [35 rows x 87 columns]

# %%
import sqlite_utils
#!rm wrc_2024_archive_results.db
_db_filepath = f"wrc_{CURRENT_YEAR}_archive_results.db"
pathlib.Path.unlink(_db_filepath) 
# db = sqlite_utils.Database("wrc_2023_results.db")

#!rm wrc_2024_12_results.db
db = sqlite_utils.Database(_db_filepath)

# %%
# db["delme"].insert_all(df_fullcal.to_dict("records"))
# db["delme"].drop()

# %%
def db_add(table, df):
    if not df.empty:
        db[table].insert_all(df.to_dict("records"), alter=True)

db_add("fullcal", getFullCalendar())
db_add("resultscal", getResultsCalendar())

# %%
# We can add alter=True to dynamically modify tables

def stageresults(row, eventId, rallyId):
    stageId = row["stageId"]
    if stageId=="FINAL":
        return
    try:
        _df_stageTimes = getStageTimes(eventId, rallyId, stageId)
        if 'event' in _df_stageTimes.columns:
            db_add("shakedown_stagetimes", _df_stageTimes)   
        else:
            db_add("stagetimes", _df_stageTimes)
    except:
        print(f"Couldn't get stagetimes for {eventId} {rallyId} {stageId}")
    try:
        _df_splitTimes = getSplitTimes(eventId, rallyId, stageId)
        if 'event' in _df_splitTimes.columns:
            db_add("shakedown_split", _df_splitTimes)   
        else:
            db_add("splittimes", _df_splitTimes)
    except:
          print(f"Couldn't get splittimes for {eventId} {rallyId} {stageId}")
    try:
        _df_Overall = getOverall(eventId, rallyId, stageId)
        if 'event' in _df_Overall.columns:
            db_add("shakedown_overall", _df_Overall)   
        else:
            db_add("overall", _df_Overall)
    except:
        print(f"Couldn't get overall for {eventId} {rallyId} {stageId}")


def rallyresults(row):
    eventId, rallyId = row[["eventId", "rallyId"]]
    db_add("retirements",getRetirements(eventId))
    db_add("penalties",getPenalties(eventId))
    db_add("startlist",getStartlist(eventId))
    db_add("itinerary",getItinerary(eventId))
    db_add("stagewinners",getStageWinners(eventId))

    df_stageDetails = getStageDetails(eventId, rallyId)
    db_add("stagedetails", df_stageDetails)
    df_stageDetails.apply(stageresults, axis=1, args=(eventId, rallyId))
    #stageresults(df_stageDetails)


def rallyresults2(row):
    eventId, rallyId = row[["eventId", "rallyId"]]
    print(eventId, rallyId, row["startDateLocal"])

_ = df_fullcal.apply(rallyresults, axis=1)

# %%
_ = df_fullcal.apply(rallyresults2, axis=1)
# Out:
# 446 477 2024-01-24T16:30:00+01:00
# 447 478 2024-02-15T09:00:00+01:00
# 448 479 2024-03-27T10:00:00+03:00
# 449 480 2024-04-18T09:00:00+02:00
# 450 481 2024-05-09T08:00:00+01:00
# 452 483 2024-05-30T18:45:00+02:00
# 453 484 2024-06-27T10:00:00+02:00
# 454 485 2024-07-18T07:31:00+03:00
# 455 486 2024-07-31T19:00:00+03:00
# 456 487 2024-09-05T09:01:00+03:00
# 457 488 2024-09-26T08:31:00-03:00
# 458 489 2024-10-17T09:30:00+02:00
# 459 490 2024-11-21T09:00:00+09:00

# %%
df_fullcal.columns
# Out:
# Index(['id', 'guid', 'title', 'location', 'startDate', 'endDate', 'eventId',
#        'rallyId', 'description', 'round', 'cvpSeriesLink', 'sponsor', 'images',
#        'season', 'competition', 'country', 'asset', '__typename', 'type',
#        'uid', 'seriesUid', 'releaseYear', 'availableOn', 'availableTill',
#        'startDateLocal', 'endDateLocal', 'finishDate', 'championship',
#        'championshipLogo'],
#       dtype='object')

# %%
getStageTimes(eventId, rallyId, stageId)
# Out:
#                                       id pos carNo  \
# 0   f0e87af5-0cfa-5c94-a792-6106abeacde9   1   #11
# 1   e3b0a0d6-ffcd-597d-8810-c9cc5e31cc13   2    #8
# 2   f2f3da23-d724-52a9-bd01-362e0e389e81   3    #4
# 3   4965f409-4d74-52b2-9a6b-c97db36bd1e7   4   #18
# 4   c58f0ad5-6dc9-5f3a-ab24-6d3306c89e06   5   #17
# 5   dee62ffc-9830-5564-97fd-b85d47ce61d2   6   #69
# 6   79c1931c-0cab-5b80-bdaa-d8674c15997e   7   #33
# 7   795c4177-f68a-57a3-ad17-d4d2851e1dbe   8   #21
# 8   c70c9ad6-e0bc-5ed7-a339-c2ace0b02885   9   #22
# 9   a0977e64-2959-5722-8be1-ab4ea8573a75  10   #20
# 10  3b1728fc-e8f6-5ae0-bdbf-56d50a7c793d  11   #26
# 11  816f6cfd-592c-5b25-88a6-516a7b851c68  12   #35
# 12  9901ae74-d1cd-5b3c-91a1-6a63c2b45a91  13   #30
# 13  3ce34efb-f423-53b3-b42c-23c03bbacba8  14   #25
# 14  000d53cc-9e41-513d-9bb8-8044e8d099a8  15   #36
# 15  28dda2bb-c6d0-5d89-8908-189ad647bc84  16   #39
# 16  0408b743-aadc-5d1e-8bbb-964f005ebf64  17   #28
# 17  7a521bae-3d60-5a3b-b073-3d1ad3c16b12  18   #38
# 18  c1b107e3-d79d-55b4-8cfc-4188ea8ae66d  19   #31
# 19  89cbef35-28bc-51e7-96c1-66b1c74f7f1c  20   #40
# 20  759b2363-6e10-5f51-a0dd-e31c074fc59d  21   #29
# 21  0576b400-4728-576e-858a-33606fd8a33e  22   #41
# 22  894b26d9-5a84-5861-9c8a-2459d3c84001  23   #37
# 23  fadf46a9-397a-51c6-b92a-2c0300c24179  24   #46
# 24  53fee654-84af-5e21-972e-066be3cbe2b7  25   #44
# 25  7113c061-23ce-5931-a074-811b78496f09  26   #49
# 26  438d0cd1-816a-579c-9a10-a65313b83d37  27   #48
# 27  b80b384e-5bd5-5ef3-b572-3611022ac6c4  28   #45
#
#                                 driverId  \
# 0   c99a2a26-bd03-5153-aaa7-684d3acb5491
# 1   6632e7ca-34bf-55b8-9cad-d060000fa794
# 2   916f5b10-fee9-5b4c-b17b-6fbbc343cc3c
# 3   298f93b1-b0ef-5af4-9f0c-e468d29abfd2
# 4   1cf9ade6-25b5-5586-8393-eacfeb943eae
# 5   d8e4bbea-3af2-5486-9ad5-a445aaec573e
# 6   ae7329c9-79b3-5d96-886c-22cca6217764
# 7   199a29d0-97f5-530f-9a5d-7ab45b1da0cc
# 8   cede2cae-3446-54d8-b9d7-7e65651ebfd1
# 9   093f0b06-7a05-5353-92ac-f5a68ae51f41
# 10  77222f77-61d8-5908-9632-24abf8556af7
# 11  e00988f4-2f7f-55f1-8ec6-a0e790578911
# 12  b487d175-4d7a-563c-bf10-8ec3dc5f0bc3
# 13  209ebf34-4d0f-528b-83a2-46c38ceb499d
# 14  0a4d6b0a-f926-56f3-aca2-049f93add127
# 15  c9cdcbc6-fd62-5aae-8f41-82a1c8ae2f69
# 16  15aa0c7e-8fbd-5923-9b70-41d012e8838d
# 17  28c1d624-1370-564a-b156-d8bf093dc22f
# 18  b3ad32a3-6975-5ee7-acf2-3c5370ccf5b4
# 19  5fe3cdf8-1caa-507e-a25c-f356e3271f4f
# 20  079fcb03-b8a5-5fd6-af92-6ba473b88aa3
# 21  53f655b1-91e6-5163-adad-f8e7e4c6a77b
# 22  754eb36a-2133-5312-b59a-f6b470c8dc54
# 23  e2464489-5926-5ac0-94a3-bdbf823bb827
# 24  a2406c6d-9a44-504b-b93e-488a2c733b46
# 25  9dbcb6d2-df46-5fa8-b75d-fdf59c9b75cc
# 26  4f12d0bb-2cbd-586a-86df-0844b79ef0d3
# 27  3ab588df-cc06-5017-8ba6-143de81a5972
#
#                                         driverCountry driverCountryImage  \
# 0                                             Belgium      Flags/BEL.png
# 1                                             Estonia      Flags/EST.png
# 2                                             Finland      Flags/FIN.png
# 3                                               Japan      Flags/JPN.png
# 4                                              France      Flags/FRA.png
# 5                                             Finland      Flags/FIN.png
# 6   United Kingdom of Great Britain and Northern I...      Flags/GBR.png
# 7                                                 ANA      Flags/ANA.png
# 8                                              Poland      Flags/POL.png
# 9                                              Norway      Flags/NOR.png
# 10                                              Japan      Flags/JPN.png
# 11                                              Japan      Flags/JPN.png
# 12                                              Japan      Flags/JPN.png
# 13                                             Poland      Flags/POL.png
# 14                                              Japan      Flags/JPN.png
# 15                                              Japan      Flags/JPN.png
# 16                                            Ireland      Flags/IRL.png
# 17                                              Japan      Flags/JPN.png
# 18                                             Canada      Flags/CAN.png
# 19                                              Japan      Flags/JPN.png
# 20                                              Spain      Flags/ESP.png
# 21                                              Japan      Flags/JPN.png
# 22                                              Japan      Flags/JPN.png
# 23                                              Japan      Flags/JPN.png
# 24                                              Japan      Flags/JPN.png
# 25                                              Japan      Flags/JPN.png
# 26                                              Japan      Flags/JPN.png
# 27                                              Japan      Flags/JPN.png
#
#                   driver                            coDriverId  \
# 0       Thierry NEUVILLE  b1b98699-0332-528a-8a80-11eb538f1ded
# 1              Ott TÄNAK  00a8a5c3-f7ba-5086-86df-1a59b7da7e26
# 2         Esapekka LAPPI  2ef28d31-4a74-5794-b720-12c327c941b6
# 3       Takamoto KATSUTA  6347a621-eade-5fff-a7b4-7c4b73651e8a
# 4        Sébastien OGIER  867cd58f-3fe3-5290-9cc5-b21cb41c523c
# 5        Kalle ROVANPERÄ  e4dd8a3f-00e9-59f7-9871-9337af6085d7
# 6            Elfyn EVANS  53e56691-fe7c-5271-9dc5-8960df28b221
# 7        Nikolay GRYAZIN  7d63ec40-0bb6-5da3-954e-846a2d40a9a1
# 8   Kajetan KAJETANOWICZ  a488aa5c-affc-5f48-a95e-0f400495fd71
# 9      Andreas MIKKELSEN  5d0fb669-fb61-5d51-805b-d09c1ac7e36a
# 10        Osamu FUKUNAGA  037327bb-b1e5-5db9-9f35-97747020724c
# 11           Hiroki ARAI  4f879f5d-2cce-5127-bf65-eb4034aee5f6
# 12          Satoshi IMAI  ce5d6a41-d103-51fe-8b44-2cb3776f8831
# 13         Daniel CHWIST  ff1f11ca-f1dd-5b29-a16d-0af9510aa46c
# 14      Tomoyuki SHINKAI  8e4b14a8-433b-5001-b586-0f5cf15edf1f
# 15        Kohsuke MURATA  4bfce1b0-99ed-55e2-8e7e-a1d52f250732
# 16         Eamonn BOLAND  a8a99c77-b74a-592e-852b-aebea61cc30c
# 17          Makoto HOTTA  3614d98b-2077-5896-a218-89d91d96c1d7
# 18          Jason BAILEY  64c84e95-2453-5d25-9309-7c7cfb8ba817
# 19         Yuta YAMAMOTO  1d8f0f30-abe3-5c8e-9ac3-f9cc9be9f3a4
# 20   Miguel DÍAZ ABOITIZ  91f64ca1-c090-5d73-9e25-ba969fdf52df
# 21    Mitsuhiro KUNISAWA  b57311ff-0e08-5f28-8806-efb80bfd6356
# 22       Yasuyuki SASAKI  2e3502eb-60d4-5f14-9469-338e2327b98c
# 23     Yasunori HAGIWARA  e6f37ce0-7731-5942-996d-63cde99f1e23
# 24        Tohru NAKAYAMA  33c345d3-dbfe-558b-b4c6-c91c819a5117
# 25        Taisuke AIHARA  5b273c48-7e5f-56c6-8890-7d6753cd88c8
# 26      Hiroyasu SHIMIZU  bba42333-aeba-5102-8f37-191cf8de0723
# 27           Koji TAKATA  a655075d-d4b8-5790-b96c-ed6480de882c
#
#                                       coDriverCountry coDriverCountryImage  \
# 0                                             Belgium        Flags/BEL.png
# 1                                             Estonia        Flags/EST.png
# 2                                             Finland        Flags/FIN.png
# 3                                             Ireland        Flags/IRL.png
# 4                                              France        Flags/FRA.png
# 5                                             Finland        Flags/FIN.png
# 6   United Kingdom of Great Britain and Northern I...        Flags/GBR.png
# 7                                                 ANA        Flags/ANA.png
# 8                                              Poland        Flags/POL.png
# 9                                              Norway        Flags/NOR.png
# 10                                              Japan        Flags/JPN.png
# 11                                              Japan        Flags/JPN.png
# 12                                        New Zealand        Flags/NZL.png
# 13                                             Poland        Flags/POL.png
# 14                                              Japan        Flags/JPN.png
# 15                                              Japan        Flags/JPN.png
# 16                                            Ireland        Flags/IRL.png
# 17                                              Japan        Flags/JPN.png
# 18                                             Canada        Flags/CAN.png
# 19                                              Japan        Flags/JPN.png
# 20                                              Spain        Flags/ESP.png
# 21                                              Japan        Flags/JPN.png
# 22                                              Japan        Flags/JPN.png
# 23                                              Japan        Flags/JPN.png
# 24                                              Japan        Flags/JPN.png
# 25                                              Japan        Flags/JPN.png
# 26                                              Japan        Flags/JPN.png
# 27                                              Japan        Flags/JPN.png
#
#     ...                team/car  teamName               teamLogo  \
# 0   ...     i20 N Rally1 HYBRID   Hyundai   teamLogo/hyundai.png
# 1   ...      Puma Rally1 HYBRID      Ford      teamLogo/ford.png
# 2   ...     i20 N Rally1 HYBRID   Hyundai   teamLogo/hyundai.png
# 3   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 4   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 5   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 6   ...  GR Yaris Rally1 HYBRID    Toyota    teamLogo/toyota.png
# 7   ...                Fabia RS     Skoda     teamLogo/skoda.png
# 8   ...                Fabia RS     Skoda     teamLogo/skoda.png
# 9   ...                Fabia RS     Skoda     teamLogo/skoda.png
# 10  ...               Fabia Evo     Skoda     teamLogo/skoda.png
# 11  ...              208 Rally4   Peugeot   teamLogo/peugeot.png
# 12  ...                      C3   Citroen   teamLogo/citroen.png
# 13  ...               Fabia Evo     Skoda     teamLogo/skoda.png
# 14  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 15  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 16  ...                      C3   Citroen   teamLogo/citroen.png
# 17  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 18  ...           Fiesta Rally3      Ford      teamLogo/ford.png
# 19  ...                      86    Toyota    teamLogo/toyota.png
# 20  ...                Fabia RS     Skoda     teamLogo/skoda.png
# 21  ...            Clio RS Line   Renault   teamLogo/renault.png
# 22  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 23  ...            WRX Sti 2015    Subaru    teamLogo/subaru.png
# 24  ...                GR Yaris    Toyota    teamLogo/toyota.png
# 25  ...                   Copen  Daihatsu  teamLogo/daihatsu.png
# 26  ...                   Yaris    Toyota    teamLogo/toyota.png
# 27  ...                GR Yaris    Toyota    teamLogo/toyota.png
#
#        eligibility     status stageId diffFirst diffPrev stageTime  \
# 0                M  Completed    6140                       4:48.8
# 1                M  Completed    6140      +2.4     +2.4    4:51.2
# 2                M  Completed    6140      +6.8     +4.4    4:55.6
# 3                   Completed    6140      +7.1     +0.2    4:55.9
# 4                M  Completed    6140      +7.3     +0.2    4:56.1
# 5                M  Completed    6140      +9.9     +2.6    4:58.7
# 6                M  Completed    6140     +13.4     +3.5    5:02.2
# 7   WRC2 (T/DC/CC)  Completed    6140     +21.4     +8.1    5:10.2
# 8     WRC2 (DC/CC)  Completed    6140     +29.7     +8.3    5:18.6
# 9       WRC2 (T/D)  Completed    6140     +30.2     +0.5    5:19.0
# 10   WRC2 (DCM/CC)  Completed    6140     +48.3    +18.0    5:37.1
# 11                  Completed    6140     +48.7     +0.5    5:37.5
# 12    WRC2 (DC/CC)  Completed    6140     +50.9     +2.3    5:39.8
# 13    WRC2 (DC/CC)  Completed    6140     +51.4     +0.5    5:40.3
# 14                  Completed    6140     +54.9     +3.5    5:43.7
# 15                  Completed    6140   +1:01.9     +6.9    5:50.7
# 16  WRC2 (DCM/CCM)  Completed    6140   +1:04.2     +2.3    5:52.9
# 17                  Completed    6140   +1:09.7     +5.6    5:58.5
# 18       WRC3 (DM)  Completed    6140   +1:11.9     +2.2    6:00.7
# 19                  Completed    6140   +1:18.0     +6.1    6:06.8
# 20   WRC2 (DCM/CC)  Completed    6140   +1:22.2     +4.2    6:11.0
# 21                  Completed    6140   +1:39.7    +17.4    6:28.5
# 22                  Completed    6140   +1:52.2    +12.5    6:40.9
# 23                  Completed    6140   +2:08.4    +16.2    6:57.2
# 24                  Completed    6140   +2:09.6     +1.2    6:58.4
# 25                  Completed    6140   +2:26.9    +17.3    7:15.7
# 26                  Completed    6140   +2:34.7     +7.8    7:23.5
# 27                  Completed    6140   +2:43.6     +8.9    7:32.4
#
#    championshipId
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
#
# [28 rows x 22 columns]

# %%
for row in db.query("select DISTINCT(eventId) from stagedetails "):
    print(row)
# Out:
# {'eventId': '353'}
# {'eventId': '354'}
# {'eventId': '355'}
# {'eventId': '356'}
# {'eventId': '357'}
# {'eventId': '358'}
# {'eventId': '359'}
# {'eventId': '360'}
# {'eventId': '361'}
# {'eventId': '362'}
# {'eventId': '363'}
# {'eventId': '364'}
# {'eventId': '365'}

# %%
# !ls -al wrc_2024_12_results.db
# Out:
# -rw-r--r--  1 tonyhirst  staff  3108864 27 Nov 00:07 wrc_2024_12_results.db

# %%
db.table_names()
# Out:
# ['fullcal',
#  'resultscal',
#  'retirements',
#  'penalties',
#  'startlist',
#  'itinerary',
#  'stagedetails',
#  'stagetimes',
#  'splittimes',
#  'overall']
